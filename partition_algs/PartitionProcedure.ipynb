# %% [markdown]
# # Import libraries

# %%
import os
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

from random_split import random_split
# from modified_mfs_split import main # Import metafeature-based split method
from geometric_split import GeometricSplit
from marginal_distribution_split import MarginalDistributionSplit

# %%
path_prefix = "../data/splitted/"

# %%
dataset_list = [
    "218_house_8L", "house", "california", "elevators", "CASP", "gas_turbine_co_and_nox_emission", 
    "CBM_1", "CBM_2", "delays_zurich_transport", "diamonds", "nyc_taxi_green_dec_2016", "house_sales", "medical_charges", 
    "MiamiHousing2016", "sulfur_1", "sulfur_2", "books", "players_22", "taxi", "bike", 
    "power_consumption", "3droad", "keggdirected", "kin40k", "protein", "tamielectric"
]

# %%
TRAIN_SIZE = 0.7
TEST_SIZE = 0.3
SEEDS = [0, 42, 19, 2, 23, 11, 37, 29, 57, 5] # 10 random SEEDs to construct CI

# %% [markdown]
# # Marginal distribution-based Splitting

# %%
for file_name in dataset_list:
    print(f"Start processing {file_name}.parquet...")
    
    data_path = f"../data/raw/{file_name}/{file_name}.parquet"
    df = pd.read_parquet(data_path)
    margin_splitter = MarginalDistributionSplit(file_name, df, TEST_SIZE, seeds = SEEDS)
    margin_splitter.covariate_shift()
    
    print(f"Successfully splitted!!!")
    print("==" * 25)

print("Complete Marginal distribution-based Partition")
# Out:
# Start processing 218_house_8L.parquet...
# Skip P19p2 feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing house.parquet...
# Skip  P27p4 feature due to insufficient test samples
# Skip  H8p2 feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing california.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing elevators.parquet...
# Skip  Q feature due to insufficient test samples
# Skip  DiffClb feature due to insufficient test samples
# Skip  DiffRollRate feature due to insufficient test samples
# Skip  SaTime1 feature due to insufficient test samples
# Skip  SaTime4 feature due to insufficient test samples
# Skip  DiffSaTime1 feature due to insufficient test samples
# Skip  DiffSaTime2 feature due to insufficient test samples
# Skip  DiffSaTime3 feature due to insufficient test samples
# Skip  DiffSaTime4 feature due to insufficient test samples
# Skip  Sa feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing CASP.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing gas_turbine_co_and_nox_emission.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_1.parquet...
# Skip lp feature due to insufficient test samples
# Skip v feature due to insufficient test samples
# Skip T1 feature due to insufficient test samples
# Skip P48 feature due to insufficient test samples
# Skip P1 feature due to insufficient test samples
# Skip Pexh feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing CBM_2.parquet...
# Skip lp feature due to insufficient test samples
# Skip v feature due to insufficient test samples
# Skip T1 feature due to insufficient test samples
# Skip P48 feature due to insufficient test samples
# Skip P1 feature due to insufficient test samples
# Skip Pexh feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing delays_zurich_transport.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 8 features
# Skip precipitation feature due to insufficient test samples
# Skip dew_point feature due to insufficient test samples
# Skip humidity feature due to insufficient test samples
# Skip dayminute feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing diamonds.parquet...
# Skip depth feature due to insufficient test samples
# Skip table feature due to insufficient test samples
# Skip y feature due to insufficient test samples
# Skip z feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing nyc_taxi_green_dec_2016.parquet...
# Skip tolls_amount feature due to insufficient test samples
# Skip total_amount feature due to insufficient test samples
# Skip lpep_dropoff_datetime_hour feature due to insufficient test samples
# Skip lpep_dropoff_datetime_minute feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing house_sales.parquet...
# Skip bedrooms feature due to insufficient test samples
# Skip bathrooms feature due to insufficient test samples
# Skip grade feature due to insufficient test samples
# Skip sqft_above feature due to insufficient test samples
# Skip yr_renovated feature due to insufficient test samples
# Skip long feature due to insufficient test samples
# Skip date_month feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing medical_charges.parquet...
# Skip Total_Discharges feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing MiamiHousing2016.parquet...
# Skip LND_SQFOOT feature due to insufficient test samples
# Skip age feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing books.parquet...
# Skip text_reviews_count feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing players_22.parquet...
# Skip overall feature due to insufficient test samples
# Skip wage_eur feature due to insufficient test samples
# Skip shooting feature due to insufficient test samples
# Skip dribbling feature due to insufficient test samples
# Skip defending feature due to insufficient test samples
# Skip physic feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing taxi.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 13 features
# Skip hour_sin feature due to insufficient test samples
# Skip hour_cos feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing bike.parquet...
# Skip temp feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing power_consumption.parquet...
# Skip draft_aft_telegram feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing 3droad.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing keggdirected.parquet...
# Skip X3 feature due to insufficient test samples
# Skip X4 feature due to insufficient test samples
# Skip X7 feature due to insufficient test samples
# Skip X8 feature due to insufficient test samples
# Skip X10 feature due to insufficient test samples
# Skip X11 feature due to insufficient test samples
# Skip X12 feature due to insufficient test samples
# Skip X14 feature due to insufficient test samples
# Skip X16 feature due to insufficient test samples
# Skip X17 feature due to insufficient test samples
# Skip X19 feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Start processing kin40k.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing protein.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing tamielectric.parquet...
# Skip X2 feature due to insufficient test samples
# Successfully splitted!!!
# ==================================================
# Complete Marginal distribution-based Partition

# %% [markdown]
# # Geometric-based Splitting

# %%
TEST_SIZE = 0.7
for file_name in dataset_list:
    print(f"Start processing {file_name}.parquet...")
    
    data_path = f"../data/raw/{file_name}/{file_name}.parquet"
    df = pd.read_parquet(data_path)
    geometry_splitter = GeometricSplit(file_name, df, TEST_SIZE, SEEDS)

    # Single Hyperball
    geometry_splitter.single_hyperball()
    
    # Multiple Hyperballs
    geometry_splitter.multiple_hyperballs(num_balls = 5)
    
    # Single Slab
    geometry_splitter.single_slab()
    
    # Semi-infinite Slab
    geometry_splitter.semi_infinite_slab()
    
    # KMeans-based Hyperballs
    geometry_splitter.kmeans_hyperballs(n_clusters = 5)
    
    print(f"Successfully splitted!!!")
    print("==" * 25)

print("Complete Geometric-based Partition")
# Out:
# Start processing keggdirected.parquet...
# Complete Single Hyperball
# Complete Multiple Hyperballs
# Complete Single Slab
# Complete Semi-infinite Slab
# Complete KMeans-based Hyperballs
# Successfully splitted!!!
# ==================================================
# Start processing kin40k.parquet...
# Complete Single Hyperball
# Complete Multiple Hyperballs
# Complete Single Slab
# Complete Semi-infinite Slab
# Complete KMeans-based Hyperballs
# Successfully splitted!!!
# ==================================================
# Start processing protein.parquet...
# Complete Single Hyperball
# Complete Multiple Hyperballs
# Complete Single Slab
# Complete Semi-infinite Slab
# Complete KMeans-based Hyperballs
# Successfully splitted!!!
# ==================================================
# Start processing tamielectric.parquet...
# Complete Single Hyperball
# Complete Multiple Hyperballs
# Complete Single Slab
# Complete Semi-infinite Slab
# Complete KMeans-based Hyperballs
# Successfully splitted!!!
# ==================================================
# Complete Geometric-based Partition

# %% [markdown]
# # Random Train/Test Split

# %%
for file_name in dataset_list:
    print(f"Start processing {file_name}.parquet...")

    random_split(file_name, SEEDS, TEST_SIZE)
    
    print(f"Successfully splitted!!!")
    print("==" * 25)

print("Complete Random Train/Test Partition")
# Out:
# Start processing 218_house_8L.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing house.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing california.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing elevators.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CASP.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing gas_turbine_co_and_nox_emission.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing delays_zurich_transport.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 9 features
# Successfully splitted!!!
# ==================================================
# Start processing diamonds.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing nyc_taxi_green_dec_2016.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing house_sales.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing medical_charges.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing MiamiHousing2016.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing books.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing players_22.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing taxi.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 14 features
# Successfully splitted!!!
# ==================================================
# Start processing bike.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing power_consumption.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing 3droad.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing keggdirected.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing kin40k.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing protein.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing tamielectric.parquet...
# Successfully splitted!!!
# ==================================================
# Complete Random Train/Test Partition

# %% [markdown]
# # Metafeature-based Splitting
#
# This approach is adopted from Paper ["Evaluating robustness of tabular models under meta-features based shifts"](https://openreview.net/pdf?id=BS68QcFppq), and is a replication of the code found in the following GitHub repository:
# [OOD_Tab_Evaluation](https://github.com/ITMO-NSS-team/OOD_Tab_Evaluation.git)

# %%
for file_name in dataset_list:
    path = f"../data/raw/{file_name}/{file_name}.parquet"

    folder_path = f"../data/splitted/{file_name}/Mfs_based_Split"

    if os.listdir(folder_path):     # list is non-empty → True
        print(f"Skip {file_name}.parquet due to splitted data exist")
        continue
    
    df = pd.read_parquet(path)
        
    # aim = mutual information (mut_inf)
    print(f"Start processing {file_name}.parquet...")
    main(file_name = file_name,
          aim = "mut_inf",
          seeds = SEEDS,
          keep_size = False       # Randomly select 800,000 samples for extensive datasets, i.e. >1M samples
        )
    print(f"Successfully splitted!!!")
    print("==" * 25)

print("Complete Metafeature (mutual information)-based Partition")
# Out:
# Skip 218_house_8L.parquet due to splitted data exist
# Skip house.parquet due to splitted data exist
# Skip california.parquet due to splitted data exist
# Skip elevators.parquet due to splitted data exist
# Skip CASP.parquet due to splitted data exist
# Skip gas_turbine_co_and_nox_emission.parquet due to splitted data exist
# Skip CBM_1.parquet due to splitted data exist
# Skip CBM_2.parquet due to splitted data exist
# Skip delays_zurich_transport.parquet due to splitted data exist
# Skip diamonds.parquet due to splitted data exist
# Skip nyc_taxi_green_dec_2016.parquet due to splitted data exist
# Skip house_sales.parquet due to splitted data exist
# Skip medical_charges.parquet due to splitted data exist
# Skip MiamiHousing2016.parquet due to splitted data exist
# Skip sulfur_1.parquet due to splitted data exist
# Skip sulfur_2.parquet due to splitted data exist
# Skip books.parquet due to splitted data exist
# Skip players_22.parquet due to splitted data exist
# Start processing taxi.parquet...
# Data: 1498813 samples, 13 features, 5715 classes
# Remove some samples due to extensive size
# New Data: 800000 samples, 13 features, 5466 classes
# Solution 1: distances=[mut_inf.mean=0.5902]
# Solution 2: distances=[mut_inf.mean=0.6850]
# Solution 3: distances=[mut_inf.mean=0.6182]
# Solution 4: distances=[mut_inf.mean=0.6383]
# Solution 5: distances=[mut_inf.mean=0.6836]
# Solution 6: distances=[mut_inf.mean=0.6848]
# Solution 7: distances=[mut_inf.mean=0.6156]
# Solution 8: distances=[mut_inf.mean=0.6670]
# Solution 9: distances=[mut_inf.mean=0.5974]
# Solution 10: distances=[mut_inf.mean=0.5887]
# Successfully splitted!!!
# ==================================================
# Skip bike.parquet due to splitted data exist
# Skip power_consumption.parquet due to splitted data exist
# Skip 3droad.parquet due to splitted data exist
# Skip keggdirected.parquet due to splitted data exist
# Skip kin40k.parquet due to splitted data exist
# Skip protein.parquet due to splitted data exist
# Skip tamielectric.parquet due to splitted data exist
# Complete Metafeature (mutual information)-based Partition
