# %% [markdown]
# # Import libraries

# %%
import os
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

from random_split import random_split
from modified_mfs_split import main # Import metafeature-based split method
from geometric_split import GeometricSplit
from marginal_distribution_split import MarginalDistributionSplit

# %%
path_prefix = "../data/splitted/"

# %%
dataset_list = [
    "218_house_8L", "house", "california", "elevators", "CASP", "gas_turbine_co_and_nox_emission", 
    "CBM_1", "CBM_2", "delays_zurich_transport", "diamonds", "nyc_taxi_green_dec_2016", "house_sales", "medical_charges", 
    "MiamiHousing2016", "sulfur_1", "sulfur_2", "books", "players_22", "taxi", "bike", 
    "power_consumption", "3droad", "keggdirected", "kin40k", "protein", "tamielectric"
]

# %%
TRAIN_SIZE = 0.7
TEST_SIZE = 0.3
SEEDS = [0, 42, 19, 2, 23, 11, 37, 29, 57, 5] # 10 random SEEDs to construct CI

# %% [markdown]
# # Marginal distribution-based Splitting

# %%
for file_name in dataset_list:
    print(f"Start processing {file_name}.parquet...")
    
    data_path = f"../data/raw/{file_name}/{file_name}.parquet"
    df = pd.read_parquet(data_path)
    margin_splitter = MarginalDistributionSplit(file_name, df, TEST_SIZE)
    margin_splitter.covariate_shift()
    
    print(f"Successfully splitted!!!")
    print("==" * 25)

print("Complete Marginal distribution-based Partition")
# Out:
# Start processing 218_house_8L.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing house.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing california.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing elevators.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CASP.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing gas_turbine_co_and_nox_emission.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing delays_zurich_transport.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 8 features
# Successfully splitted!!!
# ==================================================
# Start processing diamonds.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing nyc_taxi_green_dec_2016.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing house_sales.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing medical_charges.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing MiamiHousing2016.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing books.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing players_22.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing taxi.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 13 features
# Successfully splitted!!!
# ==================================================
# Start processing bike.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing power_consumption.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing 3droad.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing keggdirected.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing kin40k.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing protein.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing tamielectric.parquet...
# Successfully splitted!!!
# ==================================================
# Complete Marginal distribution-based Partition

# %% [markdown]
# # Geometric-based Splitting

# %%
for file_name in dataset_list:
    print(f"Start processing {file_name}.parquet...")
    
    data_path = f"../data/raw/{file_name}/{file_name}.parquet"
    df = pd.read_parquet(data_path)
    geometry_splitter = GeometricSplit(file_name, df, TEST_SIZE)

    # Single Hyperball
    geometry_splitter.single_hyperball()
    
    # Multiple Hyperballs
    geometry_splitter.multiple_hyperballs(num_balls = 5)
    
    # Single Slab
    geometry_splitter.single_slab()
    
    # Semi-infinite Slab
    geometry_splitter.semi_infinite_slab()
    
    # KMeans-based Hyperballs
    geometry_splitter.kmeans_hyperballs(n_clusters = 5)

    print(f"Successfully splitted!!!")
    print("==" * 25)

print("Complete Geometric-based Partition")
# Out:
# Start processing 218_house_8L.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing house.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing california.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing elevators.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CASP.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing gas_turbine_co_and_nox_emission.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing delays_zurich_transport.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 9 features
# Successfully splitted!!!
# ==================================================
# Start processing diamonds.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing nyc_taxi_green_dec_2016.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing house_sales.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing medical_charges.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing MiamiHousing2016.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing books.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing players_22.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing taxi.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 14 features
# Successfully splitted!!!
# ==================================================
# Start processing bike.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing power_consumption.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing 3droad.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing keggdirected.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing kin40k.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing protein.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing tamielectric.parquet...
# Successfully splitted!!!
# ==================================================
# Complete Geometric-based Partition

# %% [markdown]
# # Random Train/Test Split

# %%
for file_name in dataset_list:
    print(f"Start processing {file_name}.parquet...")

    random_split(file_name, SEEDS, TEST_SIZE)
    
    print(f"Successfully splitted!!!")
    print("==" * 25)

print("Complete Random Train/Test Partition")
# Out:
# Start processing 218_house_8L.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing house.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing california.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing elevators.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CASP.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing gas_turbine_co_and_nox_emission.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing CBM_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing delays_zurich_transport.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 9 features
# Successfully splitted!!!
# ==================================================
# Start processing diamonds.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing nyc_taxi_green_dec_2016.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing house_sales.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing medical_charges.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing MiamiHousing2016.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_1.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing sulfur_2.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing books.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing players_22.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing taxi.parquet...
# Remove some samples due to extensive size
# New Data: 800000 samples, 14 features
# Successfully splitted!!!
# ==================================================
# Start processing bike.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing power_consumption.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing 3droad.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing keggdirected.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing kin40k.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing protein.parquet...
# Successfully splitted!!!
# ==================================================
# Start processing tamielectric.parquet...
# Successfully splitted!!!
# ==================================================
# Complete Random Train/Test Partition

# %% [markdown]
# # Metafeature-based Splitting
#
# This approach is adopted from Paper ["Evaluating robustness of tabular models under meta-features based shifts"](https://openreview.net/pdf?id=BS68QcFppq), and is a replication of the code found in the following GitHub repository:
# [OOD_Tab_Evaluation](https://github.com/ITMO-NSS-team/OOD_Tab_Evaluation.git)

# %%
for file_name in dataset_list:
    path = f"../data/raw/{file_name}/{file_name}.parquet"

    folder_path = f"../data/splitted/{file_name}/Mfs_based_Split"

    if os.listdir(folder_path):     # list is non-empty → True
        print(f"Skip {file_name}.parquet due to splitted data exist")
        continue
    
    df = pd.read_parquet(path)
        
    # aim = mutual information (mut_inf)
    print(f"Start processing {file_name}.parquet...")
    main(file_name = file_name,
          aim = "mut_inf",
          seeds = SEEDS,
          keep_size = False       # Randomly select 800,000 samples for extensive datasets, i.e. >1M samples
        )
    print(f"Successfully splitted!!!")
    print("==" * 25)

print("Complete Metafeature (mutual information)-based Partition")
# Out:
# Skip 218_house_8L.parquet due to splitted data exist
# Skip house.parquet due to splitted data exist
# Skip california.parquet due to splitted data exist
# Skip elevators.parquet due to splitted data exist
# Skip CASP.parquet due to splitted data exist
# Skip gas_turbine_co_and_nox_emission.parquet due to splitted data exist
# Skip CBM_1.parquet due to splitted data exist
# Skip CBM_2.parquet due to splitted data exist
# Skip delays_zurich_transport.parquet due to splitted data exist
# Skip diamonds.parquet due to splitted data exist
# Skip nyc_taxi_green_dec_2016.parquet due to splitted data exist
# Skip house_sales.parquet due to splitted data exist
# Skip medical_charges.parquet due to splitted data exist
# Skip MiamiHousing2016.parquet due to splitted data exist
# Skip sulfur_1.parquet due to splitted data exist
# Skip sulfur_2.parquet due to splitted data exist
# Skip books.parquet due to splitted data exist
# Skip players_22.parquet due to splitted data exist
# Start processing taxi.parquet...
# Data: 1498813 samples, 13 features, 5715 classes
# Remove some samples due to extensive size
# New Data: 800000 samples, 13 features, 5466 classes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      12 # aim = mutual information (mut_inf)
#      13 print(f"Start processing {file_name}.parquet...")
# ---> 14 main(file_name = file_name,
#      15       aim = "mut_inf",
#      16       seeds = SEEDS,
#      17       keep_size = False       # Randomly select 800,000 samples for extensive datasets, i.e. >1M samples
#      18     )
#      19 print(f"Successfully splitted!!!")
#      20 print("==" * 25)
#
# File ~/Deakin/Projects/Dean_Summer_Project_2025/Out-of-distribution-data-fitting/partition_algs/modified_mfs_split.py:720, in main(file_name, aim, seeds, keep_size)
#     717     print(f"New Data: {X.shape[0]} samples, {X.shape[1]} features, {len(np.unique(y))} classes")
#     719 for idx, seed in enumerate(seeds):
# --> 720     run_split(
#     721         file=df,
#     722         target_column_name=df.columns[-1],
#     723         file_prefix_name=file_name, #output file name
#     724         meta_features=[aim],
#     725         population_size=10,
#     726         generations=25,
#     727         seed = seed,
#     728         idx = idx
#     729     )
#
# File ~/Deakin/Projects/Dean_Summer_Project_2025/Out-of-distribution-data-fitting/partition_algs/modified_mfs_split.py:670, in run_split(file, target_column_name, file_prefix_name, meta_features, population_size, generations, seed, idx)
#     664     X = X.iloc[:, 1:]
#     666 # print(f"Data: {X.shape[0]} samples, {X.shape[1]} features, {len(np.unique(y))} classes")
#     667 # print("🔄 Starting optimization...")
#     668
#     669 # Create optimizer
# --> 670 optimizer = EvolutionarySplitOptimizer(
#     671     X=X,
#     672     y=y,
#     673     test_size=0.3,
#     674     population_size=population_size,
#     675     generations=generations,
#     676     random_state=seed,
#     677     meta_features=meta_features,
#     678     file=file,
#     679     idx = idx
#     680 )
#     682 # Run optimization
#     683 results = optimizer.optimize(verbose=True)
#
# File ~/Deakin/Projects/Dean_Summer_Project_2025/Out-of-distribution-data-fitting/partition_algs/modified_mfs_split.py:114, in EvolutionarySplitOptimizer.__init__(self, X, y, test_size, meta_features, use_imbalance, population_size, generations, random_state, file, idx)
#     111 y_sample_test = self.y[sample_test_indices]
#     113 train_meta = extract_metafeatures(X_sample_train, y_sample_train, meta_features=self.meta_features)
# --> 114 test_meta = extract_metafeatures(X_sample_test, y_sample_test, meta_features=self.meta_features)
#     116 distances = distances_per_metafeature(train_meta, test_meta)
#     117 self.metafeature_names = list(distances.keys())
#
# File ~/Deakin/Projects/Dean_Summer_Project_2025/Out-of-distribution-data-fitting/partition_algs/modified_mfs_split.py:44, in extract_metafeatures(X, y, meta_features)
#      42 mfe = MFE(features=meta_features, summary="mean")
#      43 if y is not None:
# ---> 44     mfe.fit(X, y)
#      45 else:
#      46     mfe.fit(X)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pymfe/mfe.py:1142, in MFE.fit(self, X, y, transform_num, transform_cat, rescale, rescale_args, cat_cols, check_bool, precomp_groups, wildcard, suppress_warnings, verbose, **kwargs)
#    1139         warnings.filterwarnings("ignore")
#    1141     # Custom arguments from preprocessing methods
# -> 1142     self._precomp_args_ft = _internal.process_precomp_groups(
#    1143         precomp_groups=precomp_groups,
#    1144         groups=self.groups,
#    1145         wildcard=wildcard,
#    1146         suppress_warnings=suppress_warnings,
#    1147         verbose=verbose,
#    1148         **self._custom_args_ft,
#    1149         **kwargs,
#    1150     )
#    1152 self.time_precomp = time.time() - _time_start
#    1154 if verbose >= 2:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pymfe/_internal.py:1276, in process_precomp_groups(precomp_groups, groups, wildcard, suppress_warnings, verbose, custom_class_, **kwargs)
#    1273     print("\nStarted precomputing '{}'.".format(precomp_mtd_name))
#    1275 try:
# -> 1276     new_precomp_vals = precomp_mtd_callable(**kwargs)  # type: ignore
#    1278 except _EXCEPTIONS as type_err:
#    1279     new_precomp_vals = {}
#
# File /opt/anaconda3/lib/python3.11/site-packages/pymfe/info_theory.py:142, in MFEInfoTheory.precompute_entropy(cls, y, C, class_freqs, **kwargs)
#     140 if y is not None and C is not None and C.size:
#     141     if "joint_ent" not in kwargs:
# --> 142         precomp_vals["joint_ent"] = np.apply_along_axis(
#     143             func1d=cls._calc_joint_ent, axis=0, arr=C, vec_y=y
#     144         )
#     146     if "mut_inf" not in kwargs:
#     147         precomp_vals["mut_inf"] = cls.ft_mut_inf(
#     148             C=C,
#     149             y=y,
#    (...)
#     152             joint_ent=precomp_vals.get("joint_ent"),
#     153         )
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/shape_base.py:402, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     400 buff[ind0] = res
#     401 for ind in inds:
# --> 402     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     404 if not isinstance(res, matrix):
#     405     # wrap the array, to preserve subclasses
#     406     buff = res.__array_wrap__(buff)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pymfe/info_theory.py:188, in MFEInfoTheory._calc_joint_ent(cls, vec_x, vec_y, epsilon)
#     182 @classmethod
#     183 def _calc_joint_ent(
#     184     cls, vec_x: np.ndarray, vec_y: np.ndarray, epsilon: float = 1.0e-8
#     185 ) -> float:
#     186     """Compute joint entropy between ``vec_x`` and ``vec_y``."""
#     187     joint_prob_mat = (
# --> 188         pd.crosstab(vec_y, vec_x, normalize=True).values + epsilon
#     189     )
#     191     joint_ent = np.sum(
#     192         np.multiply(joint_prob_mat, np.log2(joint_prob_mat))
#     193     )
#     195     return -1.0 * joint_ent
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:711, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     707     kwargs = {"aggfunc": aggfunc}
#     709 # error: Argument 7 to "pivot_table" of "DataFrame" has incompatible type
#     710 # "**Dict[str, object]"; expected "Union[...]"
# --> 711 table = df.pivot_table(
#     712     "__dummy__",
#     713     index=unique_rownames,
#     714     columns=unique_colnames,
#     715     margins=margins,
#     716     margins_name=margins_name,
#     717     dropna=dropna,
#     718     **kwargs,  # type: ignore[arg-type]
#     719 )
#     721 # Post-process
#     722 if normalize is not False:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9190, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9173 @Substitution("")
#    9174 @Appender(_shared_docs["pivot_table"])
#    9175 def pivot_table(
#    (...)
#    9186     sort: bool = True,
#    9187 ) -> DataFrame:
#    9188     from pandas.core.reshape.pivot import pivot_table
# -> 9190     return pivot_table(
#    9191         self,
#    9192         values=values,
#    9193         index=index,
#    9194         columns=columns,
#    9195         aggfunc=aggfunc,
#    9196         fill_value=fill_value,
#    9197         margins=margins,
#    9198         dropna=dropna,
#    9199         margins_name=margins_name,
#    9200         observed=observed,
#    9201         sort=sort,
#    9202     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:99, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      96     table = concat(pieces, keys=keys, axis=1)
#      97     return table.__finalize__(data, method="pivot_table")
# ---> 99 table = __internal_pivot_table(
#     100     data,
#     101     values,
#     102     index,
#     103     columns,
#     104     aggfunc,
#     105     fill_value,
#     106     margins,
#     107     dropna,
#     108     margins_name,
#     109     observed,
#     110     sort,
#     111 )
#     112 return table.__finalize__(data, method="pivot_table")
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:169, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     166     values = list(values)
#     168 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
# --> 169 agged = grouped.agg(aggfunc)
#     171 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     172     agged = agged.dropna(how="all")
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1479, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1476 # grouper specific aggregations
#    1477 if self.grouper.nkeys > 1:
#    1478     # test_groupby_as_index_series_scalar gets here with 'not self.as_index'
# -> 1479     return self._python_agg_general(func, *args, **kwargs)
#    1480 elif args or kwargs:
#    1481     # test_pass_args_kwargs gets here (with and without as_index)
#    1482     # can't return early
#    1483     result = self._aggregate_frame(func, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1545, in DataFrameGroupBy._python_agg_general(self, func, *args, **kwargs)
#    1543 output: dict[int, ArrayLike] = {}
#    1544 for idx, (name, ser) in enumerate(obj.items()):
# -> 1545     result = self.grouper.agg_series(ser, f)
#    1546     output[idx] = result
#    1548 res = self.obj._constructor(output)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     842 if not isinstance(obj._values, np.ndarray):
#     843     # we can preserve a little bit more aggressively with EA dtype
#     844     #  because maybe_cast_pointwise_result will do a try/except
#     845     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     846     #  is sufficiently strict that it casts appropriately.
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#     852     cls = obj.dtype.construct_array_type()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     874 splitter = self._get_splitter(obj, axis=0)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#     880     if not initialized:
#     881         # We only do this validation on the first iteration
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1528, in DataFrameGroupBy._python_agg_general.<locals>.<lambda>(x)
#    1526     alias = com._builtin_table_alias[func]
#    1527     warn_alias_replacement(self, orig_func, alias)
# -> 1528 f = lambda x: func(x, *args, **kwargs)
#    1530 if self.ngroups == 0:
#    1531     # e.g. test_evaluate_with_empty_groups different path gets different
#    1532     #  result dtype in empty case.
#    1533     return self._python_apply_general(f, self._selected_obj, is_agg=True)
#
# KeyboardInterrupt:
