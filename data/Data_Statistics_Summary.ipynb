# %%
from stat_sum_func import ToParquet, DatasetStatistics

# %%
file = "taxi"
path = f"raw/{file}/{file}.parquet"
statistics_man = DatasetStatistics(path)
statistics_man.df
# Out:
#          domain  minute_oftheday_sin  minute_oftheday_cos      hour_sin  \
# 0             0            -0.156434            -0.156434 -2.588190e-01
# 1             0             0.982450             0.982450  1.000000e+00
# 2             0            -0.994056            -0.994056 -9.659258e-01
# 3             0             0.390731             0.390731  2.588190e-01
# 4             0            -0.923880            -0.923880 -9.659258e-01
# ...         ...                  ...                  ...           ...
# 1498808       3            -0.548293            -0.548293 -5.000000e-01
# 1498809       3            -0.434445            -0.434445 -2.588190e-01
# 1498810       3            -0.629320            -0.629320 -5.000000e-01
# 1498811       3             0.267238             0.267238  5.000000e-01
# 1498812       3            -0.203642            -0.203642  6.123234e-17
#
#              hour_cos  week_sin  week_cos     month_sin     month_cos  \
# 0       -2.588190e-01 -0.900969 -0.900969  6.123234e-17  6.123234e-17
# 1        1.000000e+00 -0.222521 -0.222521 -1.000000e+00 -1.000000e+00
# 2       -9.659258e-01 -0.900969 -0.900969  8.660254e-01  8.660254e-01
# 3        2.588190e-01  1.000000  1.000000 -5.000000e-01 -5.000000e-01
# 4       -9.659258e-01 -0.222521 -0.222521  6.123234e-17  6.123234e-17
# ...               ...       ...       ...           ...           ...
# 1498808 -5.000000e-01  0.623490  0.623490  5.000000e-01  5.000000e-01
# 1498809 -2.588190e-01  0.623490  0.623490  5.000000e-01  5.000000e-01
# 1498810 -5.000000e-01  0.623490  0.623490  5.000000e-01  5.000000e-01
# 1498811  5.000000e-01  0.623490  0.623490  5.000000e-01  5.000000e-01
# 1498812  6.123234e-17  0.623490  0.623490  5.000000e-01  5.000000e-01
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               -0.411012         0.452977          -0.410915
# 1               -0.411002         0.452651          -0.411108
# 2               -0.410995         0.452933          -0.411141
# 3               -0.411167         0.452444          -0.411179
# 4               -0.410961         0.453258          -0.410961
# ...                   ...              ...                ...
# 1498808         -0.436441        -0.003111          -0.436412
# 1498809         -0.436119        -0.002278          -0.435722
# 1498810         -0.436030        -0.001942          -0.436040
# 1498811         -0.436390        -0.002853          -0.436391
# 1498812         -0.435733        -0.003795          -0.435813
#
#          dropoff_latitude  trip_duration
# 0                0.452951       0.704884
# 1                0.452568       0.748243
# 2                0.452334       0.882335
# 3                0.452297       0.698107
# 4                0.453139       0.699706
# ...                   ...            ...
# 1498808         -0.003499       0.773141
# 1498809         -0.003657       0.959005
# 1498810         -0.001951       0.906989
# 1498811         -0.002853       0.519522
# 1498812         -0.003638       0.742910
#
# [1498813 rows x 14 columns]

# %%
for feature in statistics_man.df.columns:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_box()

# %%
statistics_man.print_stat_sum()
# Out:
# Number of samples : 1498813
# Number of features: 13
# ==============================
#                        dtype  missing      count    median      mean  \
# domain                 int64        0  1498813.0  0.000000  0.069245
# minute_oftheday_sin  float64        0  1498813.0 -0.156434 -0.064543
# minute_oftheday_cos  float64        0  1498813.0 -0.156434 -0.064543
# hour_sin             float64        0  1498813.0 -0.258819 -0.087534
# hour_cos             float64        0  1498813.0 -0.258819 -0.087534
# week_sin             float64        0  1498813.0 -0.222521 -0.060814
# week_cos             float64        0  1498813.0 -0.222521 -0.060814
# month_sin            float64        0  1498813.0 -0.500000 -0.173497
# month_cos            float64        0  1498813.0 -0.500000 -0.173497
# pickup_longitude     float64        0  1498813.0 -0.411012 -0.412486
# pickup_latitude      float64        0  1498813.0  0.452810  0.441493
# dropoff_longitude    float64        0  1498813.0 -0.411003 -0.412485
# dropoff_latitude     float64        0  1498813.0  0.452815  0.441502
# trip_duration        float64        0  1498813.0  0.748590  0.744064
#
#                           std       min       25%       50%       75%  \
# domain               0.429941  0.000000  0.000000  0.000000  0.000000
# minute_oftheday_sin  0.720119 -1.000000 -0.777146 -0.156434  0.678801
# minute_oftheday_cos  0.720119 -1.000000 -0.777146 -0.156434  0.678801
# hour_sin             0.705042 -1.000000 -0.707107 -0.258819  0.707107
# hour_cos             0.705042 -1.000000 -0.707107 -0.258819  0.707107
# week_sin             0.700371 -0.900969 -0.900969 -0.222521  0.623490
# week_cos             0.700371 -0.900969 -0.900969 -0.222521  0.623490
# month_sin            0.680349 -1.000000 -0.866025 -0.500000  0.500000
# month_cos            0.680349 -1.000000 -0.866025 -0.500000  0.500000
# pickup_longitude     0.012420 -0.677407 -0.411072 -0.411012 -0.410933
# pickup_latitude      0.067777 -0.031953  0.452610  0.452810  0.452976
# dropoff_longitude    0.012419 -0.677407 -0.411068 -0.411003 -0.410910
# dropoff_latitude     0.067780 -0.032034  0.452593  0.452815  0.452991
# trip_duration        0.090856  0.000000  0.689468  0.748590  0.804546
#
#                           max
# domain               3.000000
# minute_oftheday_sin  1.000000
# minute_oftheday_cos  1.000000
# hour_sin             1.000000
# hour_cos             1.000000
# week_sin             1.000000
# week_cos             1.000000
# month_sin            1.000000
# month_cos            1.000000
# pickup_longitude    -0.340753
# pickup_latitude      0.576456
# dropoff_longitude   -0.340753
# dropoff_latitude     0.488011
# trip_duration        0.999980

# %%
statistics_man.plot_corr_heatmap()
