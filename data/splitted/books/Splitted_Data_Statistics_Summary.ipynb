# %% [markdown]
# # Import libraries

# %%
from stat_sum_func import SplittedDatasetStatistics

# %% [markdown]
# # Splitted Data statistics summary

# %%
file = "books"

# %% [markdown]
# ## Random_Split

# %%
train_path = f"splitted/{file}/Random_Split/train_0.parquet"
test_path = f"splitted/{file}/Random_Split/test_0.parquet"

statistics_man = SplittedDatasetStatistics(train_path, test_path)

print("==" * 20 + "Train data Samples" + "==" * 20)
display(statistics_man.train.df)

print("==" * 20 + "Test data Samples" + "==" * 20)

display(statistics_man.test.df)
# Out:
# ========================================Train data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         592.0          820.0                92.0            4.07
# 1         179.0          497.0                 9.0            4.37
# 2         167.0        12684.0               627.0            3.81
# 3         152.0           19.0                 1.0            3.74
# 4         192.0            1.0                 1.0            3.40
# ...         ...            ...                 ...             ...
# 7238      546.0         2141.0               167.0            3.86
# 7239      304.0         5034.0               305.0            3.71
# 7240      384.0          308.0                33.0            4.22
# 7241      496.0           88.0                 8.0            4.19
# 7242      200.0         5827.0               125.0            4.31
#
# [7243 rows x 4 columns]
# ========================================Test data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         406.0          543.0                35.0            4.07
# 1         289.0        19637.0               228.0            3.90
# 2         265.0        13233.0               570.0            4.08
# 3         461.0        31384.0              2255.0            3.87
# 4         504.0         7121.0               185.0            3.91
# ...         ...            ...                 ...             ...
# 3100      480.0            1.0                 0.0            3.77
# 3101      208.0          897.0                17.0            4.48
# 3102      304.0          982.0                52.0            3.46
# 3103      342.0         5242.0                42.0            3.71
# 3104      474.0         1021.0               101.0            4.11
#
# [3105 rows x 4 columns]

# %%
statistics_man.print_stat_sum()
# Out:
# ========================================Train data Statistics Summary========================================
# Number of samples : 7243
# Number of features: 3
# ==============================
#                       dtype  missing   count  median          mean  \
# num_pages           float64        0  7243.0  293.00    331.992500
# ratings_count       float64        0  7243.0  827.00  14580.259833
# text_reviews_count  float64        0  7243.0   48.00    475.348619
# average_rating      float64        0  7243.0    3.96      3.930399
#
#                              std  min     25%     50%      75%        max
# num_pages             232.618307  0.0  192.00  293.00   408.00     4736.0
# ratings_count       77353.874644  0.0  104.00  827.00  5553.50  2530894.0
# text_reviews_count   2125.500595  0.0    9.00   48.00   247.00    86881.0
# average_rating          0.364102  0.0    3.77    3.96     4.14        5.0
# ========================================Test data Statistics Summary========================================
# Number of samples : 3105
# Number of features: 3
# ==============================
#                       dtype  missing   count  median          mean  \
# num_pages           float64        0  3105.0  300.00    336.281028
# ratings_count       float64        0  3105.0  863.00  16515.479995
# text_reviews_count  float64        0  3105.0   55.00    513.789262
# average_rating      float64        0  3105.0    3.96      3.938794
#
#                               std  min     25%     50%      75%        max
# num_pages              248.396997  0.0  200.00  300.00   412.00     6576.0
# ratings_count       116020.855310  0.0  127.00  863.00  5554.00  4597666.0
# text_reviews_count    2532.133871  0.0   10.00   55.00   260.00    94265.0
# average_rating           0.339733  0.0    3.77    3.96     4.14        5.0

# %%
statistics_man.plot_pairplot()

# %%
for feature in statistics_man.df_all.columns[:-1]:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_corr_heatmap()

# %% [markdown]
# ## Covariate_Shift

# %%
train_path = f"splitted/{file}/Covariate_Shift/train_0.parquet"
test_path = f"splitted/{file}/Covariate_Shift/test_0.parquet"

statistics_man = SplittedDatasetStatistics(train_path, test_path)

print("==" * 20 + "Train data Samples" + "==" * 20)
display(statistics_man.train.df)

print("==" * 20 + "Test data Samples" + "==" * 20)

display(statistics_man.test.df)
# Out:
# ========================================Train data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         320.0         3490.0               177.0           3.900
# 1         270.0           88.0                 4.0           4.610
# 2         322.0        70689.0              4067.0           3.640
# 3         289.0        84107.5              3136.5           4.145
# 4         288.0          412.0                37.0           4.020
# ...         ...            ...                 ...             ...
# 3111      248.0          131.0                19.0           3.960
# 3112      356.0          282.0                24.0           4.290
# 3113      238.0           24.0                 0.0           4.200
# 3114      260.0            9.0                 0.0           4.270
# 3115      313.0         3536.0               375.0           3.870
#
# [3116 rows x 4 columns]
# ========================================Test data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0       192.000         2762.0              214.00         4.22000
# 1       528.000           30.0                4.00         3.49000
# 2       409.125        10731.5              103.25         4.04875
# 3       992.000        36303.0              439.00         3.85000
# 4       395.000          204.0               19.00         3.91000
# ...         ...            ...                 ...             ...
# 7227    191.000            5.0                0.00         4.58000
# 7228    191.000            5.0                0.00         4.57000
# 7229    184.000            4.0                0.00         4.57000
# 7230    467.000           24.0                0.00         4.44000
# 7231    608.000           26.0                0.00         4.36000
#
# [7232 rows x 4 columns]

# %%
statistics_man.print_stat_sum()
# Out:
# ========================================Train data Statistics Summary========================================
# Number of samples : 3116
# Number of features: 3
# ==============================
#                       dtype  missing   count   median          mean  \
# num_pages           float64        0  3116.0   294.50    295.706181
# ratings_count       float64        0  3116.0  1187.50  15079.623590
# text_reviews_count  float64        0  3116.0    69.00    524.491975
# average_rating      float64        0  3116.0     3.91      3.881267
#
#                              std    min     25%      50%       75%        max
# num_pages              36.362497  233.0  262.00   294.50   325.125      357.0
# ratings_count       76455.754960    0.0  180.00  1187.50  6048.750  2457092.0
# text_reviews_count   2003.433829    0.0   13.00    69.00   318.250    52759.0
# average_rating          0.343532    0.0    3.73     3.91     4.070        5.0
# ========================================Test data Statistics Summary========================================
# Number of samples : 7232
# Number of features: 3
# ==============================
#                       dtype  missing   count      median          mean  \
# num_pages           float64        0  7232.0  358.000000    349.468171
# ratings_count       float64        0  7232.0  722.500000  15195.973486
# text_reviews_count  float64        0  7232.0   42.366667    470.678749
# average_rating      float64        0  7232.0    3.980000      3.955172
#
#                              std  min     25%         50%      75%        max
# num_pages             281.504950  0.0  160.00  358.000000   468.00     6576.0
# ratings_count       96197.419580  0.0   93.00  722.500000  5344.25  4597666.0
# text_reviews_count   2355.301366  0.0    8.00   42.366667   227.00    94265.0
# average_rating          0.360353  0.0    3.79    3.980000     4.16        5.0

# %%
for feature in statistics_man.df_all.columns[:-1]:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_pairplot()

# %%
statistics_man.plot_corr_heatmap()

# %% [markdown]
# ## Mfs_based_Split

# %%
train_path = f"splitted/{file}/Mfs_based_Split/train_1.parquet"
test_path = f"splitted/{file}/Mfs_based_Split/test_1.parquet"

statistics_man = SplittedDatasetStatistics(train_path, test_path)

print("==" * 20 + "Train data Samples" + "==" * 20)
display(statistics_man.train.df)

print("==" * 20 + "Test data Samples" + "==" * 20)

display(statistics_man.test.df)
# Out:
# ========================================Train data Samples========================================
#       num_pages  ratings_count  text_reviews_count    target
# 0      0.820058      -0.166828           -0.214133 -1.240833
# 1      0.319421      -0.048837           -0.170121  0.324504
# 2      2.774174       0.233104           -0.021234 -0.232294
# 3     -0.055925      -0.128679           -0.137417 -0.092219
# 4      0.259934      -0.164909           -0.207481 -0.064204
# ...         ...            ...                 ...       ...
# 7239  -0.599203      -0.167103           -0.215907  1.812799
# 7240  -0.599203      -0.167103           -0.215907  1.784784
# 7241  -0.628683      -0.167114           -0.215907  1.784784
# 7242   0.563159      -0.166894           -0.215907  1.420589
# 7243   1.156974      -0.166872           -0.215907  1.196470
#
# [7244 rows x 4 columns]
# ========================================Test data Samples========================================
#       num_pages  ratings_count  text_reviews_count    target
# 0      0.095687      -0.121424           -0.137417  0.131901
# 1      0.061996      -0.135747           -0.137417 -0.120234
# 2     -0.325458       0.150258           -0.137417  0.608155
# 3     -0.460225      -0.146133           -0.162250  0.075871
# 4     -0.026445      -0.159341           -0.203047 -0.344354
# ...         ...            ...                 ...       ...
# 3099  -1.386746      -0.164898           -0.194178 -0.288324
# 3100   0.007247      13.725396           23.179909  0.440065
# 3101  -0.527608      17.314913           24.884963  0.552125
# 3102  -0.561300      -0.139187           -0.180874 -0.848623
# 3103   0.752674      -0.133409           -0.150277 -0.372369
#
# [3104 rows x 4 columns]

# %%
statistics_man.print_stat_sum()
# Out:
# ========================================Train data Statistics Summary========================================
# Number of samples : 7244
# Number of features: 3
# ==============================
#                       dtype  missing   count    median      mean       std  \
# num_pages           float64        0  7244.0 -0.190692 -0.017943  1.060001
# ratings_count       float64        0  7244.0 -0.164115 -0.029858  0.966651
# text_reviews_count  float64        0  7244.0 -0.206594 -0.040484  0.980539
# target              float64        0  7244.0  0.075871 -0.018435  1.096675
#
#                           min       25%       50%       75%        max
# num_pages           -1.403591 -0.599203 -0.190692  0.302049  26.290949
# ratings_count       -0.167158 -0.166552 -0.164115 -0.128591  50.524872
# text_reviews_count  -0.215907 -0.213690 -0.206594 -0.160919  41.585617
# target             -11.018059 -0.484429  0.075871  0.580140   2.989428
# ========================================Test data Statistics Summary========================================
# Number of samples : 3104
# Number of features: 3
# ==============================
#                       dtype  missing   count    median      mean       std  \
# num_pages           float64        0  3104.0 -0.106463  0.041874  0.842394
# ratings_count       float64        0  3104.0 -0.136970  0.069681  1.070887
# text_reviews_count  float64        0  3104.0 -0.131874  0.094480  1.038199
# target              float64        0  3104.0  0.075871  0.043023  0.724478
#
#                          min       25%       50%       75%        max
# num_pages          -1.403591 -0.485494 -0.106463  0.348375   6.505525
# ratings_count      -0.167136 -0.155493 -0.136970 -0.033558  27.737469
# text_reviews_count -0.215907 -0.187526 -0.131874  0.008477  24.884963
# target             -4.294465 -0.400384  0.075871  0.552125   2.989428

# %%
statistics_man.plot_pairplot()

# %%
for feature in statistics_man.df_all.columns[:-1]:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_corr_heatmap()

# %% [markdown]
# ## Single_Hyperball

# %%
train_path = f"splitted/{file}/Random_Split/train_0.parquet"
test_path = f"splitted/{file}/Random_Split/test_0.parquet"

statistics_man = SplittedDatasetStatistics(train_path, test_path)

print("==" * 20 + "Train data Samples" + "==" * 20)
display(statistics_man.train.df)

print("==" * 20 + "Test data Samples" + "==" * 20)

display(statistics_man.test.df)
# Out:
# ========================================Train data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         592.0          820.0                92.0            4.07
# 1         179.0          497.0                 9.0            4.37
# 2         167.0        12684.0               627.0            3.81
# 3         152.0           19.0                 1.0            3.74
# 4         192.0            1.0                 1.0            3.40
# ...         ...            ...                 ...             ...
# 7238      546.0         2141.0               167.0            3.86
# 7239      304.0         5034.0               305.0            3.71
# 7240      384.0          308.0                33.0            4.22
# 7241      496.0           88.0                 8.0            4.19
# 7242      200.0         5827.0               125.0            4.31
#
# [7243 rows x 4 columns]
# ========================================Test data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         406.0          543.0                35.0            4.07
# 1         289.0        19637.0               228.0            3.90
# 2         265.0        13233.0               570.0            4.08
# 3         461.0        31384.0              2255.0            3.87
# 4         504.0         7121.0               185.0            3.91
# ...         ...            ...                 ...             ...
# 3100      480.0            1.0                 0.0            3.77
# 3101      208.0          897.0                17.0            4.48
# 3102      304.0          982.0                52.0            3.46
# 3103      342.0         5242.0                42.0            3.71
# 3104      474.0         1021.0               101.0            4.11
#
# [3105 rows x 4 columns]

# %%
statistics_man.print_stat_sum()
# Out:
# ========================================Train data Statistics Summary========================================
# Number of samples : 7243
# Number of features: 3
# ==============================
#                       dtype  missing   count  median          mean  \
# num_pages           float64        0  7243.0  293.00    331.992500
# ratings_count       float64        0  7243.0  827.00  14580.259833
# text_reviews_count  float64        0  7243.0   48.00    475.348619
# average_rating      float64        0  7243.0    3.96      3.930399
#
#                              std  min     25%     50%      75%        max
# num_pages             232.618307  0.0  192.00  293.00   408.00     4736.0
# ratings_count       77353.874644  0.0  104.00  827.00  5553.50  2530894.0
# text_reviews_count   2125.500595  0.0    9.00   48.00   247.00    86881.0
# average_rating          0.364102  0.0    3.77    3.96     4.14        5.0
# ========================================Test data Statistics Summary========================================
# Number of samples : 3105
# Number of features: 3
# ==============================
#                       dtype  missing   count  median          mean  \
# num_pages           float64        0  3105.0  300.00    336.281028
# ratings_count       float64        0  3105.0  863.00  16515.479995
# text_reviews_count  float64        0  3105.0   55.00    513.789262
# average_rating      float64        0  3105.0    3.96      3.938794
#
#                               std  min     25%     50%      75%        max
# num_pages              248.396997  0.0  200.00  300.00   412.00     6576.0
# ratings_count       116020.855310  0.0  127.00  863.00  5554.00  4597666.0
# text_reviews_count    2532.133871  0.0   10.00   55.00   260.00    94265.0
# average_rating           0.339733  0.0    3.77    3.96     4.14        5.0

# %%
statistics_man.plot_pairplot()

# %%
for feature in statistics_man.df_all.columns[:-1]:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_corr_heatmap()

# %% [markdown]
# ## Multiple_Hyperballs

# %%
train_path = f"splitted/{file}/Multiple_Hyperballs/train_0.parquet"
test_path = f"splitted/{file}/Multiple_Hyperballs/test_0.parquet"

statistics_man = SplittedDatasetStatistics(train_path, test_path)

print("==" * 20 + "Train data Samples" + "==" * 20)
display(statistics_man.train.df)

print("==" * 20 + "Test data Samples" + "==" * 20)

display(statistics_man.test.df)
# Out:
# ========================================Train data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0       192.000         2762.0              214.00         4.22000
# 1       528.000           30.0                4.00         3.49000
# 2       409.125        10731.5              103.25         4.04875
# 3       992.000        36303.0              439.00         3.85000
# 4       320.000         3490.0              177.00         3.90000
# ...         ...            ...                 ...             ...
# 7388    191.000            5.0                0.00         4.58000
# 7389    191.000            5.0                0.00         4.57000
# 7390    184.000            4.0                0.00         4.57000
# 7391    467.000           24.0                0.00         4.44000
# 7392    608.000           26.0                0.00         4.36000
#
# [7393 rows x 4 columns]
# ========================================Test data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         259.0           46.0                 2.0            4.14
# 1         395.0          204.0                19.0            3.91
# 2         332.0          493.0                47.0            4.30
# 3         575.0          288.0                31.0            3.85
# 4         416.0           82.0                 9.0            4.23
# ...         ...            ...                 ...             ...
# 2950      256.0          500.0                46.0            4.13
# 2951      352.0          651.0                34.0            3.62
# 2952      353.0          194.0                 7.0            3.57
# 2953      416.0          412.0                42.0            4.08
# 2954      174.0          282.0                16.0            3.90
#
# [2955 rows x 4 columns]

# %%
statistics_man.print_stat_sum()
# Out:
# ========================================Train data Statistics Summary========================================
# Number of samples : 7393
# Number of features: 3
# ==============================
#                       dtype  missing   count   median          mean  \
# num_pages           float64        0  7393.0   304.00    346.706809
# ratings_count       float64        0  7393.0  2403.00  21067.320935
# text_reviews_count  float64        0  7393.0   118.00    669.638884
# average_rating      float64        0  7393.0     3.97      3.939979
#
#                               std  min     25%      50%       75%        max
# num_pages              268.370274  0.0  192.00   304.00    425.00     6576.0
# ratings_count       106740.188296  0.0   77.00  2403.00  10455.00  4597666.0
# text_reviews_count    2646.052957  0.0    8.00   118.00    451.00    94265.0
# average_rating           0.382723  0.0    3.78     3.97      4.15        5.0
# ========================================Test data Statistics Summary========================================
# Number of samples : 2955
# Number of features: 3
# ==============================
#                       dtype  missing   count  median        mean         std  \
# num_pages           float64        0  2955.0  276.00  299.685561  125.295974
# ratings_count       float64        0  2955.0  296.00  383.987710  320.258228
# text_reviews_count  float64        0  2955.0   21.00   29.653277   27.333265
# average_rating      float64        0  2955.0    3.93    3.915252    0.281714
#
#                       min     25%     50%     75%      max
# num_pages           48.00  204.00  276.00  384.00   768.00
# ratings_count       31.00  133.50  296.00  545.00  1476.00
# text_reviews_count   0.00   10.00   21.00   41.00   195.00
# average_rating       2.61    3.74    3.93    4.11     4.73

# %%
statistics_man.plot_pairplot()

# %%
for feature in statistics_man.df_all.columns[:-1]:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_corr_heatmap()

# %% [markdown]
# ## KMeans_Hyperballs

# %%
train_path = f"splitted/{file}/KMeans_Hyperballs/train_0.parquet"
test_path = f"splitted/{file}/KMeans_Hyperballs/test_0.parquet"

statistics_man = SplittedDatasetStatistics(train_path, test_path)

print("==" * 20 + "Train data Samples" + "==" * 20)
display(statistics_man.train.df)

print("==" * 20 + "Test data Samples" + "==" * 20)

display(statistics_man.test.df)
# Out:
# ========================================Train data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         424.0       269826.0              5220.0            4.08
# 1         461.0       115201.0              1008.0            4.13
# 2         341.0       125693.0              3229.0            4.03
# 3         980.0       105950.0              3992.0            4.44
# 4         212.0       239652.0              5860.0            4.17
# ...         ...            ...                 ...             ...
# 7239      191.0            5.0                 0.0            4.58
# 7240      191.0            5.0                 0.0            4.57
# 7241      184.0            4.0                 0.0            4.57
# 7242      467.0           24.0                 0.0            4.44
# 7243      608.0           26.0                 0.0            4.36
#
# [7244 rows x 4 columns]
# ========================================Test data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0       192.000         2762.0              214.00         4.22000
# 1       528.000           30.0                4.00         3.49000
# 2       409.125        10731.5              103.25         4.04875
# 3       992.000        36303.0              439.00         3.85000
# 4       320.000         3490.0              177.00         3.90000
# ...         ...            ...                 ...             ...
# 3099    341.000          134.0               11.00         4.12000
# 3100    798.000           63.0               13.00         3.98000
# 3101    203.000          953.0               20.00         4.28000
# 3102    187.000         8921.0              207.00         4.10000
# 3103    501.000      4597666.0            94265.00         3.59000
#
# [3104 rows x 4 columns]

# %%
statistics_man.print_stat_sum()
# Out:
# ========================================Train data Statistics Summary========================================
# Number of samples : 7244
# Number of features: 3
# ==============================
#                       dtype  missing   count  median          mean  \
# num_pages           float64        0  7244.0  296.00    334.941126
# ratings_count       float64        0  7244.0  903.50  18291.085688
# text_reviews_count  float64        0  7244.0   53.00    567.852853
# average_rating      float64        0  7244.0    3.96      3.937082
#
#                              std  min     25%     50%      75%        max
# num_pages             242.832164  0.0  192.00  296.00   412.25     6576.0
# ratings_count       93415.922068  0.0  126.00  903.50  5814.00  2530894.0
# text_reviews_count   2421.392809  0.0   10.00   53.00   263.00    86881.0
# average_rating          0.355075  0.0    3.78    3.96     4.14        5.0
# ========================================Test data Statistics Summary========================================
# Number of samples : 3104
# Number of features: 3
# ==============================
#                       dtype  missing   count  median         mean  \
# num_pages           float64        0  3104.0  292.00   329.401016
# ratings_count       float64        0  3104.0  699.00  7855.915797
# text_reviews_count  float64        0  3104.0   43.00   297.918697
# average_rating      float64        0  3104.0    3.95     3.923200
#
#                              std  min     25%     50%      75%        max
# num_pages             224.409525  0.0  196.00  292.00   404.00     3342.0
# ratings_count       83589.062087  0.0   78.00  699.00  4941.00  4597666.0
# text_reviews_count   1794.971456  0.0    7.00   43.00   228.00    94265.0
# average_rating          0.361222  0.0    3.76    3.95     4.13        5.0

# %%
statistics_man.plot_pairplot()

# %%
for feature in statistics_man.df_all.columns[:-1]:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_corr_heatmap()

# %% [markdown]
# ## Single_Slab

# %%
train_path = f"splitted/{file}/Single_Slab/train_0.parquet"
test_path = f"splitted/{file}/Single_Slab/test_0.parquet"

statistics_man = SplittedDatasetStatistics(train_path, test_path)

print("==" * 20 + "Train data Samples" + "==" * 20)
display(statistics_man.train.df)

print("==" * 20 + "Test data Samples" + "==" * 20)

display(statistics_man.test.df)
# Out:
# ========================================Train data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0       192.000         2762.0              214.00         4.22000
# 1       528.000           30.0                4.00         3.49000
# 2       409.125        10731.5              103.25         4.04875
# 3       320.000         3490.0              177.00         3.90000
# 4       395.000          204.0               19.00         3.91000
# ...         ...            ...                 ...             ...
# 7238    392.000            1.0                0.00         3.79000
# 7239    735.000           75.0                0.00         4.57000
# 7240    768.000           91.0                2.00         4.56000
# 7241    467.000           24.0                0.00         4.44000
# 7242    608.000           26.0                0.00         4.36000
#
# [7243 rows x 4 columns]
# ========================================Test data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         992.0        36303.0               439.0            3.85
# 1         232.0        12613.0               392.0            4.39
# 2          32.0           11.0                 1.0            3.46
# 3         144.0           14.0                 2.0            3.73
# 4         322.0        70689.0              4067.0            3.64
# ...         ...            ...                 ...             ...
# 3100      189.0            5.0                 0.0            4.55
# 3101      189.0            6.0                 0.0            4.56
# 3102      191.0            5.0                 0.0            4.58
# 3103      191.0            5.0                 0.0            4.57
# 3104      184.0            4.0                 0.0            4.57
#
# [3105 rows x 4 columns]

# %%
statistics_man.print_stat_sum()
# Out:
# ========================================Train data Statistics Summary========================================
# Number of samples : 7243
# Number of features: 3
# ==============================
#                       dtype  missing   count  median         mean  \
# num_pages           float64        0  7243.0  318.00   358.994657
# ratings_count       float64        0  7243.0  698.00  1863.601528
# text_reviews_count  float64        0  7243.0   42.00   104.896729
# average_rating      float64        0  7243.0    3.95     3.927310
#
#                             std  min     25%     50%      75%      max
# num_pages            210.949113  0.0  227.00  318.00   423.00   2751.0
# ratings_count       2532.183185  0.0  152.00  698.00  2551.50  11649.0
# text_reviews_count   159.745463  0.0   11.00   42.00   129.00   1619.0
# average_rating         0.337892  0.0    3.76    3.95     4.13      5.0
# ========================================Test data Statistics Summary========================================
# Number of samples : 3105
# Number of features: 3
# ==============================
#                       dtype  missing   count     median          mean  \
# num_pages           float64        0  3105.0    201.000    273.293386
# ratings_count       float64        0  3105.0  13760.000  46179.491622
# text_reviews_count  float64        0  3105.0    418.000   1377.938388
# average_rating      float64        0  3105.0      3.985      3.945999
#
#                               std  min     25%        50%       75%        max
# num_pages              281.063637  0.0  120.00    201.000    371.00     6576.0
# ratings_count       161350.373059  0.0   56.00  13760.000  36334.00  4597666.0
# text_reviews_count    3969.752566  0.0    5.00    418.000   1342.00    94265.0
# average_rating           0.397682  0.0    3.79      3.985      4.15        5.0

# %%
statistics_man.plot_pairplot()

# %%
for feature in statistics_man.df_all.columns[:-1]:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_corr_heatmap()

# %% [markdown]
# ## Semi_Infinite_Slab

# %%
train_path = f"splitted/{file}/Semi_Infinite_Slab/train_0.parquet"
test_path = f"splitted/{file}/Semi_Infinite_Slab/test_0.parquet"

statistics_man = SplittedDatasetStatistics(train_path, test_path)

print("==" * 20 + "Train data Samples" + "==" * 20)
display(statistics_man.train.df)

print("==" * 20 + "Test data Samples" + "==" * 20)

display(statistics_man.test.df)
# Out:
# ========================================Train data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0       192.000         2762.0              214.00         4.22000
# 1       528.000           30.0                4.00         3.49000
# 2       409.125        10731.5              103.25         4.04875
# 3       992.000        36303.0              439.00         3.85000
# 4       320.000         3490.0              177.00         3.90000
# ...         ...            ...                 ...             ...
# 7191    392.000            1.0                0.00         3.79000
# 7192    735.000           75.0                0.00         4.57000
# 7193    768.000           91.0                2.00         4.56000
# 7194    467.000           24.0                0.00         4.44000
# 7195    608.000           26.0                0.00         4.36000
#
# [7196 rows x 4 columns]
# ========================================Test data Samples========================================
#       num_pages  ratings_count  text_reviews_count  average_rating
# 0         270.0           88.0                 4.0            4.61
# 1          32.0           11.0                 1.0            3.46
# 2         144.0           14.0                 2.0            3.73
# 3           0.0            8.0                 1.0            2.62
# 4         144.0           15.0                 0.0            3.11
# ...         ...            ...                 ...             ...
# 3147      189.0            5.0                 0.0            4.55
# 3148      189.0            6.0                 0.0            4.56
# 3149      191.0            5.0                 0.0            4.58
# 3150      191.0            5.0                 0.0            4.57
# 3151      184.0            4.0                 0.0            4.57
#
# [3152 rows x 4 columns]

# %%
statistics_man.print_stat_sum()
# Out:
# ========================================Train data Statistics Summary========================================
# Number of samples : 7196
# Number of features: 3
# ==============================
#                       dtype  missing   count       median          mean  \
# num_pages           float64        0  7196.0   356.000000    399.183551
# ratings_count       float64        0  7196.0  2579.500000  21734.741985
# text_reviews_count  float64        0  7196.0   128.000000    694.276691
# average_rating      float64        0  7196.0     3.971667      3.961729
#
#                               std  min      25%          50%       75%  \
# num_pages              250.822429  0.0  256.000   356.000000    469.25
# ratings_count       108116.046964  0.0  670.750  2579.500000  10884.25
# text_reviews_count    2678.132639  0.0   36.375   128.000000    465.25
# average_rating           0.281823  0.0    3.800     3.971667      4.15
#
#                           max
# num_pages              6576.0
# ratings_count       4597666.0
# text_reviews_count    94265.0
# average_rating            5.0
# ========================================Test data Statistics Summary========================================
# Number of samples : 3152
# Number of features: 3
# ==============================
#                       dtype  missing   count  median        mean         std  \
# num_pages           float64        0  3152.0  192.00  182.820252   94.557150
# ratings_count       float64        0  3152.0   69.00  152.977168  193.405815
# text_reviews_count  float64        0  3152.0    6.00   13.404389   19.392322
# average_rating      float64        0  3152.0    3.91    3.867141    0.480472
#
#                     min    25%     50%     75%     max
# num_pages           0.0  112.0  192.00  254.00   377.0
# ratings_count       0.0   19.0   69.00  223.00  1304.0
# text_reviews_count  0.0    2.0    6.00   17.25   195.0
# average_rating      0.0    3.7    3.91    4.11     5.0

# %%
statistics_man.plot_pairplot()

# %%
for feature in statistics_man.df_all.columns[:-1]:
    statistics_man.plot_distribution(feature)

# %%
statistics_man.plot_corr_heatmap()
