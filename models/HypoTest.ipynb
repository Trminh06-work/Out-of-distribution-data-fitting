# %%
from Experiment import Analysis

# %%
expert = Analysis(
    alpha = 0.05,
    agg_method = "median"
)

# %% [markdown]
# # Ranking

# %%
long_df = expert.construct_full_stats_table()
long_df
# Out:
# Processing:   0%|          | 0/11 [00:00<?, ?it/s]
# Processing LinearRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing PolynomialRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing KNNRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing SVMRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing DTRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing RFRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing GBRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing ABRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing XGBRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing LightGBMRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
# Processing RealMLPRegressor:   0%|          | 0/26 [00:00<?, ?it/s]
#            dataset                split             model     score
# 0     218_house_8L         Random_Split   LinearRegressor  0.000015
# 1     218_house_8L      Covariate_Shift   LinearRegressor  0.000010
# 2     218_house_8L      Mfs_based_Split   LinearRegressor  0.566695
# 3     218_house_8L     Single_Hyperball   LinearRegressor  0.000353
# 4     218_house_8L  Multiple_Hyperballs   LinearRegressor  0.000016
# ...            ...                  ...               ...       ...
# 2283  tamielectric     Single_Hyperball  RealMLPRegressor  3.470187
# 2284  tamielectric  Multiple_Hyperballs  RealMLPRegressor  3.455080
# 2285  tamielectric    KMeans_Hyperballs  RealMLPRegressor  3.476053
# 2286  tamielectric          Single_Slab  RealMLPRegressor  3.471713
# 2287  tamielectric   Semi_Infinite_Slab  RealMLPRegressor  3.475853
#
# [2288 rows x 4 columns]

# %%
split_agnostic_test = expert.split_agnostic_test(long_df)
# Out:
# Friedman chi2 = 678.6274, p=2.4281e-139
# Mean ranks (lower is better):
# model
# RealMLPRegressor       3.527473
# LightGBMRegressor      3.736264
# GBRegressor            3.967033
# XGBRegressor           4.159341
# RFRegressor            5.225275
# ABRegressor            5.296703
# LinearRegressor        7.340659
# KNNRegressor           7.928571
# PolynomialRegressor    8.054945
# DTRegressor            8.186813
# SVMRegressor           8.576923
# dtype: float64
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to      p_value       p_holm  median(other - best)
#        KNNRegressor 7.767745e-20 7.767745e-19          8.474939e-02
#         DTRegressor 1.543228e-15 1.388905e-14          7.249969e-02
#        SVMRegressor 2.889585e-15 2.311668e-14          7.305401e-02
# PolynomialRegressor 1.364539e-14 9.551772e-14          7.412530e-02
#     LinearRegressor 4.567671e-12 2.740603e-11          3.617843e-02
#         ABRegressor 1.713620e-07 8.568099e-07          9.941551e-03
#         RFRegressor 3.480173e-04 1.392069e-03          3.199158e-03
#        XGBRegressor 7.108439e-04 2.132532e-03          2.230872e-03
#   LightGBMRegressor 6.204023e-03 1.240805e-02          9.294137e-07
#         GBRegressor 2.312570e-02 2.312570e-02          1.401903e-06
#
# ✅ Best overall model (split-agnostic): RealMLPRegressor

# %%
split_wise_test = expert.split_wise_test(long_df)
# Out:
# ==========================================================================================
# SPLIT: Random_Split
# Datasets (paired blocks): 26 | Models: 11
# Friedman chi2=166.9860, p=1.16651e-30
#
# Mean ranks (lower is better):
# model
# LightGBMRegressor       2.461538
# RealMLPRegressor        2.615385
# XGBRegressor            4.153846
# GBRegressor             4.192308
# ABRegressor             5.153846
# RFRegressor             5.461538
# KNNRegressor            6.000000
# DTRegressor             8.076923
# PolynomialRegressor     8.346154
# LinearRegressor         9.153846
# SVMRegressor           10.384615
# dtype: float64
#
# Candidate best: LightGBMRegressor
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to      p_value   p_holm  median(other - best)
#        SVMRegressor 2.831221e-07 0.000003              0.169550
# PolynomialRegressor 1.043081e-06 0.000009              0.276060
#         DTRegressor 1.639128e-06 0.000013              0.040750
#     LinearRegressor 4.574656e-06 0.000032              0.109546
#        KNNRegressor 7.240474e-05 0.000434              0.026789
#        XGBRegressor 1.411438e-04 0.000706              0.010967
#         ABRegressor 2.057999e-04 0.000823              0.022578
#         RFRegressor 4.673898e-04 0.001402              0.012916
#         GBRegressor 2.139568e-03 0.004279              0.010932
#    RealMLPRegressor 2.262363e-01 0.226236              0.000046
#
# ⚠️ No single winner under split 'Random_Split'. Top group: ['LightGBMRegressor', 'RealMLPRegressor']
#
# ==========================================================================================
# SPLIT: Covariate_Shift
# Datasets (paired blocks): 26 | Models: 11
# Friedman chi2=97.6224, p=1.62834e-16
#
# Mean ranks (lower is better):
# model
# RealMLPRegressor       2.961538
# LightGBMRegressor      3.846154
# GBRegressor            4.000000
# XGBRegressor           4.576923
# RFRegressor            5.461538
# ABRegressor            5.615385
# PolynomialRegressor    6.884615
# LinearRegressor        7.230769
# KNNRegressor           8.230769
# SVMRegressor           8.269231
# DTRegressor            8.923077
# dtype: float64
#
# Candidate best: RealMLPRegressor
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to      p_value   p_holm  median(other - best)
#         DTRegressor 8.195639e-07 0.000008              0.108044
#        KNNRegressor 6.660819e-06 0.000060              0.087195
#         ABRegressor 6.294250e-05 0.000504              0.013679
#     LinearRegressor 1.090765e-03 0.007635              0.014462
#        SVMRegressor 2.139568e-03 0.012837              0.033078
# PolynomialRegressor 3.645450e-03 0.018227              0.005619
#         RFRegressor 8.166581e-03 0.032666              0.008299
#         GBRegressor 2.316558e-02 0.065200              0.000763
#   LightGBMRegressor 3.151485e-02 0.065200              0.001513
#        XGBRegressor 2.173322e-02 0.065200              0.002792
#
# ⚠️ No single winner under split 'Covariate_Shift'. Top group: ['RealMLPRegressor', 'GBRegressor', 'LightGBMRegressor', 'XGBRegressor']
#
# ==========================================================================================
# SPLIT: Mfs_based_Split
# Datasets (paired blocks): 26 | Models: 11
# Friedman chi2=118.2098, p=1.16744e-20
#
# Mean ranks (lower is better):
# model
# RealMLPRegressor       2.807692
# LightGBMRegressor      3.615385
# GBRegressor            3.923077
# XGBRegressor           3.961538
# ABRegressor            5.423077
# RFRegressor            5.423077
# LinearRegressor        7.653846
# KNNRegressor           7.730769
# PolynomialRegressor    7.884615
# DTRegressor            8.500000
# SVMRegressor           9.076923
# dtype: float64
#
# Candidate best: RealMLPRegressor
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to      p_value   p_holm  median(other - best)
#        SVMRegressor 1.043081e-07 0.000001              0.144803
#         DTRegressor 1.490116e-07 0.000001              0.093773
#     LinearRegressor 8.195639e-07 0.000007              0.119515
# PolynomialRegressor 1.311302e-06 0.000009              0.114173
#        KNNRegressor 1.347065e-05 0.000081              0.088696
#         RFRegressor 9.858012e-04 0.004929              0.017968
#         ABRegressor 3.969222e-03 0.015877              0.022210
#         GBRegressor 2.316558e-02 0.069497              0.007166
#        XGBRegressor 5.241016e-02 0.104820              0.010289
#   LightGBMRegressor 3.821972e-01 0.382197              0.002555
#
# ⚠️ No single winner under split 'Mfs_based_Split'. Top group: ['RealMLPRegressor', 'GBRegressor', 'XGBRegressor', 'LightGBMRegressor']
#
# ==========================================================================================
# SPLIT: Single_Hyperball
# Datasets (paired blocks): 26 | Models: 11
# Friedman chi2=88.3566, p=1.1335e-14
#
# Mean ranks (lower is better):
# model
# GBRegressor            3.730769
# LightGBMRegressor      4.038462
# XGBRegressor           4.230769
# RealMLPRegressor       4.384615
# RFRegressor            4.923077
# ABRegressor            5.038462
# DTRegressor            7.346154
# LinearRegressor        7.346154
# KNNRegressor           7.615385
# SVMRegressor           8.538462
# PolynomialRegressor    8.807692
# dtype: float64
#
# Candidate best: GBRegressor
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to  p_value   p_holm  median(other - best)
# PolynomialRegressor 0.000262 0.002623          3.103896e-01
#        KNNRegressor 0.001205 0.009817          7.661871e-02
#        SVMRegressor 0.001091 0.009817          1.311621e-01
#         DTRegressor 0.004317 0.030221          2.367054e-02
#     LinearRegressor 0.004317 0.030221          7.957760e-02
#         ABRegressor 0.010986 0.054929          6.726276e-03
#         RFRegressor 0.145688 0.582753          3.261598e-04
#   LightGBMRegressor 0.291112 0.873337          5.399504e-07
#    RealMLPRegressor 0.450329 0.900659          8.978290e-07
#        XGBRegressor 0.470150 0.900659         -5.280157e-08
#
# ⚠️ No single winner under split 'Single_Hyperball'. Top group: ['GBRegressor', 'ABRegressor', 'RFRegressor', 'LightGBMRegressor', 'RealMLPRegressor', 'XGBRegressor']
#
# ==========================================================================================
# SPLIT: Multiple_Hyperballs
# Datasets (paired blocks): 26 | Models: 11
# Friedman chi2=95.7762, p=3.80346e-16
#
# Mean ranks (lower is better):
# model
# RealMLPRegressor       3.346154
# LightGBMRegressor      3.384615
# GBRegressor            4.192308
# XGBRegressor           4.576923
# RFRegressor            5.423077
# ABRegressor            5.615385
# PolynomialRegressor    6.730769
# LinearRegressor        7.269231
# SVMRegressor           8.269231
# KNNRegressor           8.384615
# DTRegressor            8.807692
# dtype: float64
#
# Candidate best: RealMLPRegressor
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to  p_value   p_holm  median(other - best)
#        KNNRegressor 0.000008 0.000080          1.012440e-01
#         DTRegressor 0.000083 0.000748          9.554238e-02
#        SVMRegressor 0.008807 0.070454          2.689004e-02
#         ABRegressor 0.013598 0.095185          1.429055e-02
#     LinearRegressor 0.039786 0.238718          1.123693e-02
# PolynomialRegressor 0.044515 0.238718          7.677415e-03
#         RFRegressor 0.047037 0.238718          3.947260e-03
#        XGBRegressor 0.058241 0.238718          2.950133e-03
#         GBRegressor 0.218723 0.437447          8.688896e-05
#   LightGBMRegressor 0.317425 0.437447         -4.891956e-07
#
# ⚠️ No single winner under split 'Multiple_Hyperballs'. Top group: ['RealMLPRegressor', 'SVMRegressor', 'ABRegressor', 'LinearRegressor', 'PolynomialRegressor', 'RFRegressor', 'XGBRegressor', 'GBRegressor', 'LightGBMRegressor']
#
# ==========================================================================================
# SPLIT: KMeans_Hyperballs
# Datasets (paired blocks): 26 | Models: 11
# Friedman chi2=93.3776, p=1.14272e-15
#
# Mean ranks (lower is better):
# model
# RealMLPRegressor       3.230769
# LightGBMRegressor      3.923077
# XGBRegressor           4.115385
# GBRegressor            4.307692
# ABRegressor            5.192308
# RFRegressor            5.423077
# LinearRegressor        7.346154
# PolynomialRegressor    7.730769
# KNNRegressor           7.923077
# DTRegressor            8.230769
# SVMRegressor           8.576923
# dtype: float64
#
# Candidate best: RealMLPRegressor
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to  p_value   p_holm  median(other - best)
#        KNNRegressor 0.000010 0.000095              0.052831
#         DTRegressor 0.000063 0.000566              0.111179
#         ABRegressor 0.005523 0.044181              0.010771
# PolynomialRegressor 0.005523 0.044181              0.017068
#        SVMRegressor 0.008167 0.048999              0.042944
#     LinearRegressor 0.010214 0.051072              0.031504
#   LightGBMRegressor 0.013598 0.054392              0.004329
#        XGBRegressor 0.029677 0.089032              0.006464
#         GBRegressor 0.058241 0.116482              0.001090
#         RFRegressor 0.071358 0.116482              0.002996
#
# ⚠️ No single winner under split 'KMeans_Hyperballs'. Top group: ['RealMLPRegressor', 'LinearRegressor', 'LightGBMRegressor', 'XGBRegressor', 'GBRegressor', 'RFRegressor']
#
# ==========================================================================================
# SPLIT: Single_Slab
# Datasets (paired blocks): 26 | Models: 11
# Friedman chi2=121.1469, p=2.96046e-21
#
# Mean ranks (lower is better):
# model
# GBRegressor            3.500000
# LightGBMRegressor      3.576923
# XGBRegressor           3.653846
# RealMLPRegressor       4.076923
# ABRegressor            4.884615
# RFRegressor            5.076923
# LinearRegressor        7.423077
# DTRegressor            7.730769
# KNNRegressor           7.884615
# SVMRegressor           8.884615
# PolynomialRegressor    9.307692
# dtype: float64
#
# Candidate best: GBRegressor
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to  p_value   p_holm  median(other - best)
#         DTRegressor 0.000063 0.000629          5.180870e-02
#        SVMRegressor 0.000095 0.000856          2.226276e-01
#        KNNRegressor 0.000182 0.001283          1.657096e-01
# PolynomialRegressor 0.000160 0.001283          1.117119e-01
#     LinearRegressor 0.000373 0.002236          7.023846e-02
#         ABRegressor 0.061335 0.306674          1.906002e-03
#         RFRegressor 0.157626 0.630503          2.065043e-03
#    RealMLPRegressor 0.233888 0.701663          1.573773e-06
#   LightGBMRegressor 0.717434 1.000000          7.893164e-08
#        XGBRegressor 0.588908 1.000000         -1.118706e-07
#
# ⚠️ No single winner under split 'Single_Slab'. Top group: ['GBRegressor', 'ABRegressor', 'RFRegressor', 'RealMLPRegressor', 'LightGBMRegressor', 'XGBRegressor']
#
# ==========================================================================================
# SPLIT: Semi_Infinite_Slab
# Datasets (paired blocks): 26 | Models: 11
# Friedman chi2=97.5874, p=1.65473e-16
#
# Mean ranks (lower is better):
# model
# LightGBMRegressor      3.769231
# RealMLPRegressor       3.884615
# XGBRegressor           4.000000
# GBRegressor            4.115385
# RFRegressor            4.846154
# ABRegressor            5.307692
# LinearRegressor        7.115385
# KNNRegressor           7.730769
# DTRegressor            7.769231
# SVMRegressor           8.423077
# PolynomialRegressor    9.038462
# dtype: float64
#
# Candidate best: LightGBMRegressor
#
# Post-hoc (Holm-corrected Wilcoxon vs best):
#          compare_to  p_value   p_holm  median(other - best)
#         DTRegressor 0.000109 0.001087          2.678760e-02
#        KNNRegressor 0.000141 0.001270          5.631039e-02
#        SVMRegressor 0.001330 0.010643          8.488364e-02
# PolynomialRegressor 0.001775 0.012428          1.743688e-01
#     LinearRegressor 0.004317 0.025904          3.307450e-02
#         ABRegressor 0.078683 0.393413          2.218271e-03
#         RFRegressor 0.163821 0.655282          3.610807e-05
#         GBRegressor 0.509958 1.000000          5.449431e-08
#    RealMLPRegressor 0.947590 1.000000         -7.370139e-03
#        XGBRegressor 0.382197 1.000000          1.570854e-06
#
# ⚠️ No single winner under split 'Semi_Infinite_Slab'. Top group: ['LightGBMRegressor', 'ABRegressor', 'RFRegressor', 'GBRegressor', 'RealMLPRegressor', 'XGBRegressor']
#
# ##########################################################################################
# SPLIT-WISE SUMMARY
#               split  datasets_used  models   friedman_p    best_candidate                                                                                                                                                                  conclusion
#     Covariate_Shift             26      11 1.628336e-16  RealMLPRegressor                                                                                         TOP_GROUP: ['RealMLPRegressor', 'GBRegressor', 'LightGBMRegressor', 'XGBRegressor']
#   KMeans_Hyperballs             26      11 1.142717e-15  RealMLPRegressor                                                       TOP_GROUP: ['RealMLPRegressor', 'LinearRegressor', 'LightGBMRegressor', 'XGBRegressor', 'GBRegressor', 'RFRegressor']
#     Mfs_based_Split             26      11 1.167442e-20  RealMLPRegressor                                                                                         TOP_GROUP: ['RealMLPRegressor', 'GBRegressor', 'XGBRegressor', 'LightGBMRegressor']
# Multiple_Hyperballs             26      11 3.803455e-16  RealMLPRegressor TOP_GROUP: ['RealMLPRegressor', 'SVMRegressor', 'ABRegressor', 'LinearRegressor', 'PolynomialRegressor', 'RFRegressor', 'XGBRegressor', 'GBRegressor', 'LightGBMRegressor']
#        Random_Split             26      11 1.166515e-30 LightGBMRegressor                                                                                                                        TOP_GROUP: ['LightGBMRegressor', 'RealMLPRegressor']
#  Semi_Infinite_Slab             26      11 1.654732e-16 LightGBMRegressor                                                           TOP_GROUP: ['LightGBMRegressor', 'ABRegressor', 'RFRegressor', 'GBRegressor', 'RealMLPRegressor', 'XGBRegressor']
#    Single_Hyperball             26      11 1.133499e-14       GBRegressor                                                           TOP_GROUP: ['GBRegressor', 'ABRegressor', 'RFRegressor', 'LightGBMRegressor', 'RealMLPRegressor', 'XGBRegressor']
#         Single_Slab             26      11 2.960459e-21       GBRegressor                                                           TOP_GROUP: ['GBRegressor', 'ABRegressor', 'RFRegressor', 'RealMLPRegressor', 'LightGBMRegressor', 'XGBRegressor']
#
# ##########################################################################################
# LATEX ROWS (mean ranks per split; red=best, blue=tied-with-best)
#
# LinearRegressor & 9.15 & 7.23 & 7.65 & 7.35 & \textcolor{blue}{7.27} & \textcolor{blue}{7.35} & 7.42 & 7.12 \\
#
# PolynomialRegressor & 8.35 & 6.88 & 7.88 & 8.81 & \textcolor{blue}{6.73} & 7.73 & 9.31 & 9.04 \\
#
# KNNRegressor & 6.00 & 8.23 & 7.73 & 7.62 & 8.38 & 7.92 & 7.88 & 7.73 \\
#
# SVMRegressor & 10.38 & 8.27 & 9.08 & 8.54 & \textcolor{blue}{8.27} & 8.58 & 8.88 & 8.42 \\
#
# DTRegressor & 8.08 & 8.92 & 8.50 & 7.35 & 8.81 & 8.23 & 7.73 & 7.77 \\
#
# RFRegressor & 5.46 & 5.46 & 5.42 & \textcolor{blue}{4.92} & \textcolor{blue}{5.42} & \textcolor{blue}{5.42} & \textcolor{blue}{5.08} & \textcolor{blue}{4.85} \\
#
# GBRegressor & 4.19 & \textcolor{blue}{4.00} & \textcolor{blue}{3.92} & \textcolor{red}{3.73} & \textcolor{blue}{4.19} & \textcolor{blue}{4.31} & \textcolor{red}{3.50} & \textcolor{blue}{4.12} \\
#
# ABRegressor & 5.15 & 5.62 & 5.42 & \textcolor{blue}{5.04} & \textcolor{blue}{5.62} & 5.19 & \textcolor{blue}{4.88} & \textcolor{blue}{5.31} \\
#
# XGBRegressor & 4.15 & \textcolor{blue}{4.58} & \textcolor{blue}{3.96} & \textcolor{blue}{4.23} & \textcolor{blue}{4.58} & \textcolor{blue}{4.12} & \textcolor{blue}{3.65} & \textcolor{blue}{4.00} \\
#
# LightGBMRegressor & \textcolor{red}{2.46} & \textcolor{blue}{3.85} & \textcolor{blue}{3.62} & \textcolor{blue}{4.04} & \textcolor{blue}{3.38} & \textcolor{blue}{3.92} & \textcolor{blue}{3.58} & \textcolor{red}{3.77} \\
#
# RealMLPRegressor & \textcolor{blue}{2.62} & \textcolor{red}{2.96} & \textcolor{red}{2.81} & \textcolor{blue}{4.38} & \textcolor{red}{3.35} & \textcolor{red}{3.23} & \textcolor{blue}{4.08} & \textcolor{blue}{3.88} \\

# %% [markdown]
# # Performance Tables

# %%
expert.performance_table(model_name = "RealMLPRegressor")
# Out:
# Processing RealMLPRegressor (RMSE):   0%|          | 0/26 [00:00<?, ?it/s]
# Processing RealMLPRegressor (MAE):   0%|          | 0/26 [00:00<?, ?it/s]
# Processing RealMLPRegressor (sMAPE):   0%|          | 0/26 [00:00<?, ?it/s]
# \#1
#  & $0 / 0 / 0.64$ & $\textcolor{blue}{0 / 0 / 0.64}$ & $0.41 / 0.2 / 0.42$ & $0 / 0 / 0.82$ & $0 / 0 / 0.65$ & $0 / 0 / 0.65$ & $0 / 0 / 0.83$ & $0 / 0 / 0.49$ \\
#
# \#2
#  & $0 / 0 / 0.65$ & $\textcolor{blue}{0 / 0 / 0.68}$ & $0.44 / 0.21 / 0.46$ & $0 / 0 / 0.87$ & $0 / 0 / 0.59$ & $0 / 0 / 0.64$ & $0 / 0 / 0.83$ & $0 / 0 / 0.59$ \\
#
# \#3
#  & $0 / 0 / 0.61$ & $0 / 0 / 0.61$ & $0.58 / 0.39 / 0.68$ & $0 / 0 / 0.78$ & $\textcolor{blue}{0 / 0 / 0.6}$ & $0 / 0 / 0.62$ & $0 / 0 / 0.74$ & $\textcolor{red}{0 / 0 / 0.69}$ \\
#
# \#4
#  & $42.7 / 31.7 / 0.54$ & $43.8 / 32.5 / 0.55$ & $\textcolor{blue}{0.26 / 0.18 / 0.46}$ & $45.2 / 33.8 / 0.75$ & $42.6 / 31.6 / 0.57$ & $45.1 / 32.9 / 0.59$ & $45.5 / 33.8 / 0.65$ & $42.7 / 31.7 / 0.47$ \\
#
# \#5
#  & $\textcolor{blue}{0.1 / 0.07 / 0.65}$ & $0.15 / 0.11 / 0.93$ & $0.78 / 0.56 / 0.79$ & $0.16 / 0.12 / 1.05$ & $0.12 / 0.09 / 0.8$ & $0.13 / 0.09 / 0.85$ & $0.16 / 0.12 / 1.04$ & $0.16 / 0.12 / 1.07$ \\
#
# \#6
#  & $0 / 0 / 0.26$ & $\textcolor{blue}{0 / 0 / 0.29}$ & $0.03 / 0.03 / 0.15$ & $0.02 / 0.01 / 0.1$ & $0 / 0 / 0.17$ & $0 / 0 / 0.27$ & $0 / 0 / 0.09$ & $0.01 / 0 / 0.07$ \\
#
# \#7
#  & $7.14 / 5.33 / 0.2$ & $55.5 / 44.9 / 0.99$ & $\textcolor{blue}{0.17 / 0.13 / 0.19}$ & $107 / 83.7 / 1.26$ & $41.8 / 29.2 / 0.69$ & $81.4 / 69.6 / 1.25$ & $113 / 86.6 / 1.17$ & $113 / 87.6 / 1.17$ \\
#
# \#8
#  & $39.9 / 22.3 / 0.34$ & $110 / 89 / 1.05$ & $\textcolor{blue}{1.28 / 0.97 / 1.12}$ & $221 / 183 / 1.31$ & $141 / 103 / 1.03$ & $142 / 114 / 1.15$ & $210 / 171 / 1.3$ & $215 / 173 / 1.29$ \\
#
# \#9
#  & $\textcolor{blue}{0.31 / 0.26 / 1.6}$ & $0.32 / 0.27 / 1.68$ & $0.99 / 0.84 / 1.7$ & $0.33 / 0.29 / 1.78$ & $0.32 / 0.26 / 1.64$ & $0.32 / 0.28 / 1.71$ & $0.33 / 0.3 / 1.76$ & $0.34 / 0.29 / 1.62$ \\
#
# \#10
#  & $0.23 / 0.18 / 0.37$ & $0.27 / 0.22 / 0.97$ & $0.49 / 0.39 / 0.13$ & $0.34 / 0.25 / 0.3$ & $\textcolor{blue}{0.22 / 0.18 / 0.35}$ & $0.29 / 0.23 / 0.3$ & $0.28 / 0.22 / 0.28$ & $0.31 / 0.24 / 0.28$ \\
#
# \#11
#  & $1.09 / 0.68 / 0.8$ & $1.2 / 0.75 / 0.83$ & $\textcolor{blue}{0.67 / 0.42 / 0.79}$ & $1.77 / 1.14 / 0.86$ & $0.89 / 0.57 / 0.85$ & $1.58 / 1.07 / 0.98$ & $1.63 / 0.91 / 0.79$ & $1.79 / 1.09 / 0.82$ \\
#
# \#12
#  & $0.66 / 0.46 / 0.53$ & $0.64 / 0.46 / 0.55$ & $\textcolor{blue}{0.34 / 0.25 / 0.56}$ & $1.03 / 0.73 / 0.64$ & $0.59 / 0.43 / 0.57$ & $0.72 / 0.51 / 0.58$ & $1 / 0.71 / 0.6$ & $1 / 0.71 / 0.58$ \\
#
# \#13
#  & $0.25 / 0.16 / 0.24$ & $0.21 / 0.13 / 0.43$ & $\textcolor{blue}{0.18 / 0.11 / 0.25}$ & $0.92 / 0.55 / 0.18$ & $0.22 / 0.14 / 0.27$ & $0.26 / 0.17 / 0.24$ & $0.56 / 0.36 / 0.17$ & $0.3 / 0.2 / 0.15$ \\
#
# \#14
#  & $0.5 / 0.34 / 0.49$ & $0.57 / 0.4 / 0.58$ & $\textcolor{blue}{0.28 / 0.19 / 0.47}$ & $0.77 / 0.53 / 0.77$ & $0.68 / 0.5 / 0.64$ & $1.63 / 1.24 / 0.8$ & $0.75 / 0.53 / 0.66$ & $1.59 / 1.15 / 0.71$ \\
#
# \#15
#  & $12.6 / 7.28 / 1.19$ & $16 / 8.85 / 1.31$ & $\textcolor{blue}{0.88 / 0.41 / 1.28}$ & $60.2 / 31.3 / 1.48$ & $20.1 / 9.64 / 1.34$ & $67 / 39 / 1.46$ & $31.3 / 17.8 / 1.42$ & $30.3 / 15.4 / 1.41$ \\
#
# \#16
#  & $13.4 / 9.21 / 1.3$ & $15.1 / 10.1 / 1.43$ & $\textcolor{blue}{1.23 / 0.75 / 1.44}$ & $26.9 / 21.1 / 1.44$ & $17.4 / 12.7 / 1.49$ & $26.4 / 19.6 / 1.48$ & $24 / 17.7 / 1.38$ & $24.7 / 18.5 / 1.46$ \\
#
# \#17
#  & $2.58 / 1.72 / 1.42$ & $2.18 / 1.54 / 1.45$ & $\textcolor{blue}{0.59 / 0.46 / 1.42}$ & $1.67 / 1.33 / 1.4$ & $3.02 / 1.91 / 1.47$ & $2.7 / 1.75 / 1.4$ & $2.83 / 2.16 / 1.48$ & $5.52 / 3.29 / 1.49$ \\
#
# \#18
#  & $\textcolor{red}{0 / 0 / 0.11}$ & $\textcolor{red}{0 / 0 / 0.08}$ & $\textcolor{red}{0.01 / 0.01 / 0.03}$ & $\textcolor{red}{0 / 0 / 0.1}$ & $\textcolor{green}{0 / 0 / 0.11}$ & $\textcolor{red}{0 / 0 / 0.36}$ & $\textcolor{red}{0 / 0 / 0.11}$ & $0 / 0 / 0.13$ \\
#
# \#19
#  & $5.93 / 3.96 / 0.73$ & $5.95 / 4.03 / 0.8$ & $\textcolor{blue}{0.51 / 0.35 / 0.74}$ & $6.65 / 4.26 / 0.77$ & $5.37 / 3.7 / 0.71$ & $5.77 / 3.81 / 0.73$ & $6.2 / 4.11 / 0.75$ & $5.74 / 3.92 / 0.73$ \\
#
# \#20
#  & $3.65 / 2.89 / 1.05$ & $3.88 / 3.09 / 1.14$ & $\textcolor{blue}{0.77 / 0.62 / 1.04}$ & $5.8 / 4.74 / 1.17$ & $4.01 / 3.19 / 1.14$ & $3.93 / 3.17 / 1.2$ & $4.04 / 3.21 / 1.11$ & $3.86 / 3.15 / 1.18$ \\
#
# \#21
#  & $\textcolor{blue}{0 / 0 / 0.11}$ & $0 / 0 / 0.21$ & $0.19 / 0.13 / 0.19$ & $0 / 0 / 0.3$ & $0 / 0 / 0.23$ & $0 / 0 / 0.21$ & $0 / 0 / 0.28$ & $0 / 0 / 0.28$ \\
#
# \#22
#  & $\textcolor{blue}{0.01 / 0.01 / 0.43}$ & $0.04 / 0.03 / 0.96$ & $0.55 / 0.36 / 0.74$ & $0.04 / 0.03 / 0.93$ & $0.03 / 0.02 / 0.65$ & $0.02 / 0.02 / 0.6$ & $0.03 / 0.02 / 0.8$ & $0.03 / 0.02 / 0.81$ \\
#
# \#23
#  & $\textcolor{blue}{0.06 / 0.03 / 0.1}$ & $0.25 / 0.16 / 0.23$ & $0.09 / 0.05 / 0.13$ & $0.48 / 0.35 / 0.15$ & $0.18 / 0.11 / 0.17$ & $0.12 / 0.06 / 0.09$ & $0.31 / 0.2 / 0.14$ & $0.33 / 0.22 / 0.09$ \\
#
# \#24
#  & $\textcolor{blue}{0.06 / 0.04 / 0.14}$ & $0.07 / 0.05 / 0.16$ & $0.1 / 0.07 / 0.2$ & $0.21 / 0.13 / 0.28$ & $0.09 / 0.06 / 0.17$ & $0.1 / 0.06 / 0.19$ & $0.12 / 0.07 / 0.21$ & $0.15 / 0.09 / 0.25$ \\
#
# \#25
#  & $\textcolor{blue}{0.73 / 0.49 / 0.62}$ & $1.1 / 0.82 / 0.91$ & $0.92 / 0.71 / 1.01$ & $1.23 / 0.95 / 1.12$ & $0.91 / 0.66 / 0.77$ & $0.93 / 0.67 / 0.86$ & $1.21 / 0.93 / 1.11$ & $1.33 / 1.03 / 1.15$ \\
#
# \#26
#  & $3.45 / 2.98 / 1.95$ & $3.45 / 2.98 / 1.96$ & $\textcolor{blue}{1.01 / 0.87 / 1.94}$ & $3.47 / 3.01 / 1.89$ & $3.46 / 2.99 / 1.92$ & $3.48 / 3.01 / 1.94$ & $3.47 / 3.01 / 1.91$ & $3.48 / 3.02 / 1.92$ \\
