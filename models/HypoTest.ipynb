# %%
from Experiment import Analysis

# %%
expert = Analysis(
    alpha = 0.05,
    agg_method = "median"
)

# %% [markdown]
# # Ranking

# %%
long_df = expert.construct_full_stats_table()
long_df

# %%
split_agnostic_test = expert.split_agnostic_test(long_df)

# %%
split_wise_test = expert.split_wise_test(long_df)

# %% [markdown]
# # Performance Tables

# %%
expert.performance_table(model_name = "FTTransformerRegressor")

# %% [markdown]
# # Comparision of different train/test selection of Geometry-based approaches

# %%
original_df = expert.construct_full_stats_table()
original_df

# %%
another_df = expert.construct_full_stats_table(dir_path = "Results_add/")
another_df

# %%
split_agnostic_test = expert.split_agnostic_test(another_df)

# %%
split_wise_test = expert.split_wise_test(another_df)

# %%
expert.side_exp_performance_table(model_name = "FTTransformerRegressor")
# Out:
# Processing FTTransformerRegressor (RMSE):   0%|          | 0/26 [00:00<?, ?it/s]
# Processing FTTransformerRegressor (RMSE):   0%|          | 0/26 [00:00<?, ?it/s]
# Processing FTTransformerRegressor (MAE):   0%|          | 0/26 [00:00<?, ?it/s]
# Processing FTTransformerRegressor (sMAPE):   0%|          | 0/26 [00:00<?, ?it/s]
# \#1
#  & $\textcolor{BrickRed}{0 / 0 / 0.72}$ & $\textcolor{ForestGreen}{0 / 0 / 0.85}$ & $\textcolor{BrickRed}{0 / 0 / 0.66}$ & $\textcolor{BrickRed}{0 / 0 / 0.73}$ & $\textcolor{ForestGreen}{0 / 0 / 0.97}$ \\
#
# \#2
#  & $\textcolor{BrickRed}{0 / 0 / 0.73}$ & $\textcolor{ForestGreen}{0 / 0 / 0.77}$ & $\textcolor{ForestGreen}{0 / 0 / 0.66}$ & $\textcolor{BrickRed}{0 / 0 / 0.62}$ & $\textcolor{ForestGreen}{0 / 0 / 1.01}$ \\
#
# \#3
#  & $\textcolor{BrickRed}{0 / 0 / 0.68}$ & $\textcolor{ForestGreen}{0 / 0 / 0.71}$ & $\textcolor{BrickRed}{0 / 0 / 0.67}$ & $\textcolor{BrickRed}{0 / 0 / 0.68}$ & $\textcolor{ForestGreen}{0 / 0 / 0.71}$ \\
#
# \#4
#  & $\textcolor{BrickRed}{44.7 / 31.7 / 0.46}$ & $\textcolor{ForestGreen}{46 / 33.4 / 0.52}$ & $\textcolor{BrickRed}{46.1 / 32.8 / 0.58}$ & $\textcolor{BrickRed}{45.3 / 32.6 / 0.49}$ & $\textcolor{ForestGreen}{49.4 / 34.6 / 0.7}$ \\
#
# \#5
#  & $\textcolor{ForestGreen}{0.14 / 0.11 / 1.01}$ & $\textcolor{ForestGreen}{0.13 / 0.1 / 0.91}$ & $\textcolor{ForestGreen}{0.13 / 0.1 / 1.07}$ & $\textcolor{BrickRed}{0.14 / 0.11 / 1}$ & $\textcolor{BrickRed}{0.13 / 0.11 / 1.37}$ \\
#
# \#6
#  & $\textcolor{BrickRed}{0.01 / 0.01 / 0.08}$ & $\textcolor{ForestGreen}{0.01 / 0 / 0.19}$ & $\textcolor{BrickRed}{0 / 0 / 0.38}$ & $\textcolor{BrickRed}{0 / 0 / 0.24}$ & $\textcolor{BrickRed}{0.01 / 0 / 0.21}$ \\
#
# \#7
#  & $\textcolor{ForestGreen}{115 / 98.9 / 1.48}$ & $\textcolor{BrickRed}{83.6 / 70.7 / 1.45}$ & $\textcolor{ForestGreen}{115 / 104 / 1.51}$ & $\textcolor{BrickRed}{102 / 86.2 / 1.44}$ & $\textcolor{BrickRed}{107 / 91.4 / 1.44}$ \\
#
# \#8
#  & $\textcolor{BrickRed}{143 / 121 / 1.41}$ & $\textcolor{ForestGreen}{150 / 127 / 1.56}$ & $\textcolor{ForestGreen}{134 / 116 / 1.57}$ & $\textcolor{BrickRed}{151 / 125 / 1.39}$ & $\textcolor{BrickRed}{167 / 137 / 1.41}$ \\
#
# \#9
#  & $\textcolor{BrickRed}{0.32 / 0.27 / 1.65}$ & $\textcolor{ForestGreen}{0.33 / 0.27 / 1.64}$ & $\textcolor{ForestGreen}{0.32 / 0.28 / 1.72}$ & $\textcolor{BrickRed}{0.32 / 0.26 / 1.63}$ & $\textcolor{ForestGreen}{0.33 / 0.27 / 1.51}$ \\
#
# \#10
#  & $\textcolor{BrickRed}{0.25 / 0.2 / 0.33}$ & $\textcolor{ForestGreen}{0.29 / 0.22 / 0.34}$ & $\textcolor{ForestGreen}{0.28 / 0.23 / 0.32}$ & $\textcolor{BrickRed}{0.25 / 0.2 / 0.35}$ & $\textcolor{BrickRed}{0.29 / 0.22 / 0.27}$ \\
#
# \#11
#  & $\textcolor{BrickRed}{0.98 / 0.64 / 0.89}$ & $\textcolor{ForestGreen}{1.56 / 1 / 0.82}$ & $\textcolor{BrickRed}{1.19 / 0.88 / 0.9}$ & $\textcolor{BrickRed}{1.01 / 0.65 / 0.82}$ & $\textcolor{BrickRed}{1.14 / 0.75 / 0.84}$ \\
#
# \#12
#  & $\textcolor{BrickRed}{0.61 / 0.45 / 0.57}$ & $\textcolor{ForestGreen}{1.13 / 0.8 / 0.58}$ & $\textcolor{BrickRed}{0.66 / 0.49 / 0.57}$ & $\textcolor{BrickRed}{0.63 / 0.47 / 0.55}$ & $\textcolor{BrickRed}{0.73 / 0.56 / 0.69}$ \\
#
# \#13
#  & $\textcolor{BrickRed}{0.22 / 0.14 / 0.19}$ & $\textcolor{ForestGreen}{0.42 / 0.23 / 0.2}$ & $\textcolor{BrickRed}{0.26 / 0.16 / 0.18}$ & $\textcolor{BrickRed}{0.23 / 0.14 / 0.24}$ & $\textcolor{ForestGreen}{0.46 / 0.31 / 0.16}$ \\
#
# \#14
#  & $\textcolor{ForestGreen}{0.95 / 0.7 / 0.76}$ & $\textcolor{ForestGreen}{0.95 / 0.71 / 0.66}$ & $\textcolor{BrickRed}{0.77 / 0.6 / 0.78}$ & $\textcolor{ForestGreen}{0.77 / 0.53 / 0.71}$ & $\textcolor{BrickRed}{0.54 / 0.39 / 0.66}$ \\
#
# \#15
#  & $\textcolor{BrickRed}{16.2 / 9.61 / 1.28}$ & $\textcolor{ForestGreen}{23.4 / 13.7 / 1.41}$ & $\textcolor{BrickRed}{21.6 / 13.2 / 1.45}$ & $\textcolor{BrickRed}{13.7 / 7.79 / 1.28}$ & $\textcolor{BrickRed}{23.1 / 12.2 / 1.47}$ \\
#
# \#16
#  & $\textcolor{BrickRed}{20.2 / 13.8 / 1.52}$ & $\textcolor{ForestGreen}{23.3 / 15.4 / 1.5}$ & $\textcolor{BrickRed}{17.8 / 13.6 / 1.53}$ & $\textcolor{BrickRed}{19.3 / 13.7 / 1.46}$ & $\textcolor{BrickRed}{19.1 / 12.5 / 1.48}$ \\
#
# \#17
#  & $\textcolor{ForestGreen}{3.07 / 2.06 / 1.56}$ & $\textcolor{BrickRed}{2.24 / 1.6 / 1.41}$ & $\textcolor{BrickRed}{2.62 / 1.76 / 1.51}$ & $\textcolor{ForestGreen}{3.38 / 2.18 / 1.53}$ & $\textcolor{BrickRed}{1.78 / 1.41 / 1.43}$ \\
#
# \#18
#  & $\textcolor{BrickRed}{0 / 0 / 0.19}$ & $\textcolor{ForestGreen}{0 / 0 / 0.25}$ & $\textcolor{BrickRed}{0 / 0 / 0.1}$ & $\textcolor{BrickRed}{0 / 0 / 0.21}$ & $\textcolor{BrickRed}{0 / 0 / 0.08}$ \\
#
# \#19
#  & $\textcolor{ForestGreen}{8.06 / 5.87 / 1.01}$ & $\textcolor{BrickRed}{7.36 / 4.95 / 0.82}$ & $\textcolor{ForestGreen}{8.15 / 5.86 / 1.01}$ & $\textcolor{ForestGreen}{8.2 / 6 / 1.03}$ & $\textcolor{ForestGreen}{8.12 / 5.88 / 1.02}$ \\
#
# \#20
#  & $\textcolor{BrickRed}{3.5 / 2.8 / 1.1}$ & $\textcolor{ForestGreen}{4.25 / 3.35 / 1.12}$ & $\textcolor{BrickRed}{3.81 / 3.05 / 1.11}$ & $\textcolor{BrickRed}{3.77 / 3.01 / 1.05}$ & $\textcolor{ForestGreen}{4.22 / 3.34 / 1.08}$ \\
#
# \#21
#  & $\textcolor{ForestGreen}{0 / 0 / 0.24}$ & $\textcolor{ForestGreen}{0 / 0 / 0.22}$ & $\textcolor{ForestGreen}{0 / 0 / 0.24}$ & $\textcolor{BrickRed}{0 / 0 / 0.24}$ & $\textcolor{ForestGreen}{0 / 0 / 0.23}$ \\
#
# \#22
#  & $\textcolor{BrickRed}{0.04 / 0.03 / 0.79}$ & $\textcolor{ForestGreen}{0.04 / 0.03 / 0.82}$ & $\textcolor{ForestGreen}{0.03 / 0.02 / 0.82}$ & $\textcolor{BrickRed}{0.03 / 0.02 / 0.77}$ & $\textcolor{ForestGreen}{0.04 / 0.03 / 0.97}$ \\
#
# \#23
#  & $\textcolor{BrickRed}{0.17 / 0.12 / 0.1}$ & $\textcolor{ForestGreen}{0.12 / 0.07 / 0.22}$ & $\textcolor{BrickRed}{0.07 / 0.04 / 0.16}$ & $\textcolor{BrickRed}{0.13 / 0.09 / 0.1}$ & $\textcolor{ForestGreen}{40.1 / 36.9 / 1.81}$ \\
#
# \#24
#  & $\textcolor{BrickRed}{0.22 / 0.15 / 0.37}$ & $\textcolor{ForestGreen}{0.28 / 0.2 / 0.44}$ & $\textcolor{ForestGreen}{0.2 / 0.14 / 0.33}$ & $\textcolor{BrickRed}{0.17 / 0.12 / 0.3}$ & $\textcolor{ForestGreen}{0.4 / 0.27 / 0.54}$ \\
#
# \#25
#  & $\textcolor{ForestGreen}{1.15 / 0.92 / 1.07}$ & $\textcolor{ForestGreen}{1 / 0.77 / 0.92}$ & $\textcolor{BrickRed}{0.95 / 0.71 / 0.87}$ & $\textcolor{ForestGreen}{1.16 / 0.91 / 1.04}$ & $\textcolor{ForestGreen}{1.59 / 1.27 / 1.17}$ \\
#
# \#26
#  & $\textcolor{BrickRed}{3.47 / 3.01 / 1.89}$ & $\textcolor{ForestGreen}{3.46 / 3 / 1.9}$ & $\textcolor{BrickRed}{3.45 / 2.99 / 1.87}$ & $\textcolor{ForestGreen}{3.47 / 3.01 / 1.88}$ & $\textcolor{BrickRed}{3.46 / 3 / 1.83}$ \\
