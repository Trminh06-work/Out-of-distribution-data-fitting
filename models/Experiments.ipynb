# %% [markdown]
# # Import libraries and Environment setup

# %%
import gc # clean-up space
from Experiment import EvaluateModel
from Models import ModelConfig

# %%
config = ModelConfig(
    use_optim = False,
    metric = "rmse",
    n_splits = 3,
    seed = 42
)

# %% [markdown]
# # Linear Regression with Huber Loss

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "LinearRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # Polynomial Regression

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "PolynomialRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # K-Neareast Neighbours Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "KNNRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # SVM Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "SVMRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # Decision Tree Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "DTRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # Random Forest Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "RFRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # Gradient Boosting Regressor

# %%
evaluator = None
gc.collect() 
evaluator = EvaluateModel(config, model_name = "GBRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # AdaBoost Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "ABRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # XGBoost Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "XGBRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # LightGBM Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "LightGBMRegressor")

# %%
evaluator.evaluate()

# %% [markdown]
# # RealMLP Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "RealMLPRegressor")

# %%
evaluator.evaluate()
# Out:
# ...
# Processing CASP splits:   0%|          | 0/5 [00:00<?, ?it/s]
# Processing gas_turbine_co_and_nox_emission splits:   0%|          | 0/5 [00:00<?, ?it/s]
# ...
# tamielectric/Semi_Infinite_Slab:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# # ResNet Regressor

# %%
evaluator = None
gc.collect()
evaluator = EvaluateModel(config, model_name = "ResnetRegressor")

# %%
evaluator.evaluate()
# Out:
# ...
# CASP/Semi_Infinite_Slab:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing gas_turbine_co_and_nox_emission splits:   0%|          | 0/5 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/Single_Hyperball:   0%|          | 0/10 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/Multiple_Hyperballs:   0%|          | 0/10 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/KMeans_Hyperballs:   0%|          | 0/10 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/Single_Slab:   0%|          | 0/10 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/Semi_Infinite_Slab:   0%|          | 0/10 [00:00<?, ?it/s]
# ...
# tamielectric/Semi_Infinite_Slab:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# # FT–Transformer Regressor

# %%
evaluator = None
gc.collect()
?-
evaluator = EvaluateModel(config, model_name = "FTTransformerRegressor")

# %%
evaluator.evaluate()
# Out:
# ...
# CASP/Semi_Infinite_Slab:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing gas_turbine_co_and_nox_emission splits:   0%|          | 0/5 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/Single_Hyperball:   0%|          | 0/10 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/Multiple_Hyperballs:   0%|          | 0/10 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/KMeans_Hyperballs:   0%|          | 0/10 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/Single_Slab:   0%|          | 0/10 [00:00<?, ?it/s]
# gas_turbine_co_and_nox_emission/Semi_Infinite_Slab:   0%|          | 0/10 [00:00<?, ?it/s]
# ...
# tamielectric/Semi_Infinite_Slab:   0%|          | 0/10 [00:00<?, ?it/s]
